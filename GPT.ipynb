# %% [markdown]
# ### 0. Загрузка данных

# %%
# !curl -L -o ~/pythonProj/GPT-Poetry/19-000-russian-poems.zip https://www.kaggle.com/api/v1/datasets/download/grafstor/19-000-russian-poems
# !unzip 19-000-russian-poems.zip

# %% [markdown]
# ### 1. Обработка текста

# %%
import pandas as pd

data = pd.read_csv("poems.csv")
data.columns
# Out:
# Index(['writer', 'poem', 'text'], dtype='object')

# %%
min_length = data['text'].str.len().min()
max_length = data['text'].str.len().max()
min_length, max_length
# Out:
# (21.0, 213425.0)

# %%
import re

data['text'] = data['text'].str.lower()
data['text'] = data['text'].apply(lambda x: re.sub(r'[^а-яё\n.,!?;:()\"\'\s-]', '', x) if pd.notnull(x) else x)
data['text'] = data['text'].str.replace('\u2003', ' ')
data['text'] = data['text'].str.replace('\xa0', ' ')
data['text'] = data['text'].str.replace('\u2004', ' ')
text = ''.join(data['text'].dropna())
unique_chars = set(text)

print(unique_chars)
# Out:
# {'ж', ',', 'в', ';', 'ш', '"', 'и', 'р', '\n', 'к', '?', 'д', 'ц', 'л', 'щ', '.', 'м', 'с', 'ю', 'ы', 'х', 'ь', 'г', 'э', 'ъ', 'я', 'й', 'т', '-', 'о', '!', 'ч', 'ё', 'з', 'а', 'п', ':', '(', 'ф', ' ', ')', 'у', 'е', 'н', 'б'}

# %% [markdown]
# ## 2. Токенизация

# %%
token_to_ind = {char: idx for idx, char in enumerate(unique_chars)}
ind_to_token = {idx: char for char, idx in token_to_ind.items()}

print(token_to_ind)
print(ind_to_token)
# Out:
# {'ж': 0, ',': 1, 'в': 2, ';': 3, 'ш': 4, '"': 5, 'и': 6, 'р': 7, '\n': 8, 'к': 9, '?': 10, 'д': 11, 'ц': 12, 'л': 13, 'щ': 14, '.': 15, 'м': 16, 'с': 17, 'ю': 18, 'ы': 19, 'х': 20, 'ь': 21, 'г': 22, 'э': 23, 'ъ': 24, 'я': 25, 'й': 26, 'т': 27, '-': 28, 'о': 29, '!': 30, 'ч': 31, 'ё': 32, 'з': 33, 'а': 34, 'п': 35, ':': 36, '(': 37, 'ф': 38, ' ': 39, ')': 40, 'у': 41, 'е': 42, 'н': 43, 'б': 44}
# {0: 'ж', 1: ',', 2: 'в', 3: ';', 4: 'ш', 5: '"', 6: 'и', 7: 'р', 8: '\n', 9: 'к', 10: '?', 11: 'д', 12: 'ц', 13: 'л', 14: 'щ', 15: '.', 16: 'м', 17: 'с', 18: 'ю', 19: 'ы', 20: 'х', 21: 'ь', 22: 'г', 23: 'э', 24: 'ъ', 25: 'я', 26: 'й', 27: 'т', 28: '-', 29: 'о', 30: '!', 31: 'ч', 32: 'ё', 33: 'з', 34: 'а', 35: 'п', 36: ':', 37: '(', 38: 'ф', 39: ' ', 40: ')', 41: 'у', 42: 'е', 43: 'н', 44: 'б'}

# %% [markdown]
# #### Bytepair токенизация

# %%
class BytePairTokenize:
    def __init__(self, text : str, ignore_set : set[str]):
        self.unique_chars = set(text)
        self.token_to_ind = {char: idx for idx, char in enumerate(self.unique_chars)}
        self.ind_to_token = {idx: char for char, idx in self.token_to_ind.items()}
        self.ignore_set = ignore_set

        self.token_to_ind['<pad>'] = len(self.token_to_ind)
        self.ind_to_token[len(self.token_to_ind) - 1] = '<pad>'

        self.token_to_ind['<start>'] = len(self.token_to_ind)
        self.ind_to_token[len(self.token_to_ind) - 1] = '<start>'

        self.token_to_ind['<end>'] = len(self.token_to_ind)
        self.ind_to_token[len(self.token_to_ind) - 1] = '<end>'

        self.text_list_token = [self.token_to_ind[char] for char in text]
    
    def find_max_freq_pairs(self, count):
        pair_dict = dict()
        for i in range(len(self.text_list_token) - 1):
            char1 = self.ind_to_token[self.text_list_token[i]]
            char2 = self.ind_to_token[self.text_list_token[i + 1]]
            if char1 not in self.ignore_set and char2 not in self.ignore_set:
                pair = (char1, char2)
                if pair in pair_dict:
                    pair_dict[pair] += 1
                else:
                    pair_dict[pair] = 1

        sorted_pairs = sorted(pair_dict.items(), key=lambda x: x[1], reverse=True)
        return [pair for pair, freq in sorted_pairs[:count]]
    
    def update_tokens(self, max_pairs):
        text_list_default = []
        i = 0
        while i < len(self.text_list_token) - 1:
            if (self.ind_to_token[self.text_list_token[i]], self.ind_to_token[self.text_list_token[i + 1]]) in max_pairs:
                text_list_default.append(self.token_to_ind[self.ind_to_token[self.text_list_token[i]] + self.ind_to_token[self.text_list_token[i + 1]]])
                i += 2
            else:
                text_list_default.append(self.text_list_token[i])
                i += 1
        if i == len(self.text_list_token) - 1:
            text_list_default.append(self.text_list_token[i])
        self.text_list_token = text_list_default

    def fit(self, count, iterations):
        for i in range(iterations):
            max_pairs = self.find_max_freq_pairs(count)
            print("max_pairs:", max_pairs)
            for pair in max_pairs:
                new_token = pair[0] + pair[1]
                self.token_to_ind[new_token] = len(self.token_to_ind)
                self.ind_to_token[len(self.token_to_ind) - 1] = new_token
            self.update_tokens(max_pairs)
        
    def process_poemes(self, data):
        max_token_size = max(len(k) for k in self.token_to_ind.keys())
        tokenized_poems = []
        for poem in data:
            i = 0
            tokenized_poem = []
            while i < len(poem):
                for j in range(max_token_size, 0, -1):
                    substring = poem[i:i+j]
                    if substring in self.token_to_ind.keys():
                        tokenized_poem.append(self.token_to_ind[substring])
                        i += j
                        break
                else:
                    if i < len(poem):
                        raise ValueError(f"No matching token found for character '{poem[i]}' at position {i}")

            tokenized_poems.append(tokenized_poem)
        return tokenized_poems

# %%
bpt = BytePairTokenize(text=text[:int(1e7)], ignore_set={char for char in unique_chars if char not in 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'})
bpt.fit(10, 500)
# Out:
# max_pairs: [('с', 'т'), ('н', 'е'), ('н', 'а'), ('н', 'о'), ('т', 'о'), ('р', 'а'), ('п', 'о'), ('р', 'о'), ('е', 'н'), ('е', 'т')]
# max_pairs: [('в', 'о'), ('к', 'о'), ('л', 'и'), ('к', 'а'), ('л', 'а'), ('г', 'о'), ('р', 'е'), ('е', 'р'), ('н', 'ы'), ('л', 'о')]
# max_pairs: [('н', 'и'), ('д', 'а'), ('и', 'т'), ('в', 'а'), ('з', 'а'), ('т', 'ь'), ('м', 'о'), ('р', 'и'), ('л', 'ь'), ('д', 'о')]
# max_pairs: [('л', 'е'), ('с', 'я'), ('к', 'и'), ('р', 'у'), ('м', 'и'), ('в', 'е'), ('т', 'е'), ('е', 'м'), ('д', 'е'), ('б', 'о')]
# max_pairs: [('б', 'е'), ('т', 'а'), ('в', 'ы'), ('с', 'о'), ('в', 'и'), ('т', 'ы'), ('с', 'ь'), ('м', 'а'), ('с', 'е'), ('ч', 'а')]
# max_pairs: [('б', 'ы'), ('д', 'у'), ('м', 'е'), ('х', 'о'), ('ст', 'а'), ('ч', 'то'), ('н', 'у'), ('о', 'т'), ('п', 'ро'), ('ны', 'й')]
# max_pairs: [('д', 'и'), ('т', 'и'), ('ж', 'е'), ('л', 'ю'), ('л', 'я'), ('п', 'а'), ('п', 'ри'), ('и', 'з'), ('л', 'у'), ('но', 'й')]
# max_pairs: [('ка', 'к'), ('ст', 'о'), ('к', 'у'), ('е', 'й'), ('ст', 'ь'), ('р', 'ы'), ('ш', 'и'), ('с', 'а'), ('г', 'а'), ('ч', 'и')]
# max_pairs: [('м', 'у'), ('о', 'н'), ('с', 'и'), ('б', 'у'), ('ен', 'ь'), ('ц', 'а'), ('м', 'ы'), ('в', 'ет'), ('ра', 'з'), ('л', 'ы')]
# max_pairs: [('н', 'ь'), ('ж', 'а'), ('ч', 'е'), ('ш', 'ь'), ('д', 'ы'), ('п', 'е'), ('п', 'у'), ('ж', 'и'), ('ш', 'е'), ('в', 'ер')]
# max_pairs: [('р', 'я'), ('о', 'б'), ('ст', 'и'), ('в', 'се'), ('м', 'ен'), ('с', 'ко'), ('п', 'ер'), ('и', 'х'), ('н', 'я'), ('с', 'ка')]
# max_pairs: [('п', 'ре'), ('ш', 'а'), ('м', 'не'), ('б', 'а'), ('л', 'ен'), ('по', 'д'), ('т', 'у'), ('с', 'у'), ('г', 'и'), ('ны', 'х')]
# max_pairs: [('д', 'ет'), ('во', 'й'), ('бе', 'з'), ('ит', 'ь'), ('с', 'во'), ('ч', 'у'), ('не', 'т'), ('ст', 'ра'), ('в', 'с'), ('в', 'у')]
# max_pairs: [('ц', 'е'), ('з', 'о'), ('п', 'и'), ('з', 'на'), ('г', 'у'), ('ра', 'с'), ('д', 'ру'), ('ко', 'й'), ('ны', 'е'), ('д', 'ь')]
# max_pairs: [('е', 'го'), ('г', 'да'), ('б', 'и'), ('с', 'к'), ('э', 'то'), ('ж', 'ен'), ('м', 'ер'), ('ю', 'т'), ('с', 'ла'), ('щ', 'и')]
# max_pairs: [('та', 'к'), ('д', 'ит'), ('ит', 'е'), ('л', 'ет'), ('с', 'ки'), ('не', 'й'), ('с', 'ле'), ('л', 'ся'), ('ч', 'ер'), ('с', 'ер')]
# max_pairs: [('ч', 'ь'), ('с', 'ло'), ('т', 'во'), ('х', 'а'), ('г', 'ла'), ('в', 'ь'), ('в', 'ен'), ('щ', 'е'), ('я', 'т'), ('мо', 'й')]
# max_pairs: [('во', 'з'), ('с', 'ы'), ('но', 'го'), ('на', 'я'), ('д', 'но'), ('к', 'то'), ('б', 'я'), ('мен', 'я'), ('ны', 'м'), ('ш', 'у')]
# max_pairs: [('з', 'ы'), ('г', 'де'), ('п', 'ра'), ('в', 'но'), ('с', 'ли'), ('к', 'ро'), ('ет', 'ся'), ('ко', 'м'), ('к', 'е'), ('в', 'з')]
# max_pairs: [('ен', 'и'), ('с', 'вет'), ('на', 'д'), ('ко', 'гда'), ('г', 'ро'), ('м', 'я'), ('р', 'ь'), ('ст', 'ы'), ('к', 'ра'), ('ж', 'у')]
# max_pairs: [('о', 'на'), ('з', 'ем'), ('п', 'ла'), ('пер', 'е'), ('щ', 'а'), ('ч', 'ем'), ('д', 'ля'), ('ль', 'ко'), ('во', 'т'), ('в', 'я')]
# max_pairs: [('бе', 'с'), ('ст', 'у'), ('бы', 'л'), ('ли', 'сь'), ('то', 'м'), ('г', 'ра'), ('б', 'ра'), ('с', 'по'), ('сер', 'д'), ('го', 'ло')]
# max_pairs: [('но', 'м'), ('г', 'е'), ('и', 'м'), ('на', 'м'), ('ст', 'ро'), ('к', 'ры'), ('с', 'лу'), ('та', 'м'), ('п', 'ы'), ('е', 'е')]
# max_pairs: [('т', 'я'), ('ж', 'из'), ('г', 'ру'), ('мо', 'л'), ('ни', 'к'), ('в', 'ра'), ('в', 'ши'), ('д', 'ни'), ('к', 'ру'), ('с', 'ча')]
# max_pairs: [('ст', 'во'), ('на', 'с'), ('по', 'л'), ('д', 'ень'), ('лю', 'б'), ('вы', 'й'), ('ко', 'в'), ('те', 'бя'), ('бо', 'й'), ('ст', 'е')]
# max_pairs: [('ц', 'ы'), ('ть', 'ся'), ('что', 'б'), ('ч', 'но'), ('ки', 'й'), ('до', 'л'), ('г', 'ля'), ('т', 'ра'), ('б', 'ле'), ('го', 'во')]
# max_pairs: [('ж', 'но'), ('б', 'ро'), ('то', 'лько'), ('б', 'ла'), ('т', 'ер'), ('д', 'ер'), ('ро', 'д'), ('дру', 'г'), ('к', 'ре'), ('те', 'бе')]
# max_pairs: [('во', 'л'), ('т', 'ре'), ('ла', 'сь'), ('т', 'ру'), ('вс', 'ё'), ('не', 'м'), ('ч', 'ит'), ('ит', 'а'), ('пре', 'д'), ('с', 'ме')]
# max_pairs: [('ч', 'ет'), ('с', 'но'), ('ль', 'но'), ('до', 'м'), ('т', 'ри'), ('ро', 'м'), ('ж', 'да'), ('ф', 'и'), ('е', 'сли'), ('ем', 'у')]
# max_pairs: [('з', 'де'), ('те', 'м'), ('в', 'ст'), ('у', 'м'), ('ме', 'ч'), ('ст', 'ре'), ('ж', 'ет'), ('го', 'р'), ('г', 'лу'), ('и', 'ль')]
# max_pairs: [('лы', 'й'), ('б', 'ли'), ('то', 'й'), ('с', 'мер'), ('в', 'ла'), ('бы', 'ть'), ('х', 'и'), ('а', 'н'), ('б', 'ер'), ('ва', 'л')]
# max_pairs: [('е', 'ще'), ('з', 'и'), ('у', 'ж'), ('п', 'я'), ('ва', 'м'), ('ва', 'ть'), ('к', 'рас'), ('ра', 'бо'), ('д', 'я'), ('о', 'ди')]
# max_pairs: [('г', 'ре'), ('ко', 'н'), ('о', 'ста'), ('с', 'вя'), ('нь', 'я'), ('о', 'к'), ('р', 'ет'), ('м', 'ет'), ('д', 'ен'), ('с', 'ку')]
# max_pairs: [('ни', 'й'), ('ну', 'ю'), ('бо', 'ль'), ('ц', 'и'), ('с', 'мо'), ('до', 'й'), ('ми', 'р'), ('нь', 'е'), ('ни', 'м'), ('ф', 'а')]
# max_pairs: [('ень', 'я'), ('лю', 'бо'), ('че', 'го'), ('пе', 'ча'), ('ли', 'шь'), ('с', 'лы'), ('пер', 'ь'), ('ва', 'я'), ('ц', 'вет'), ('ско', 'й')]
# max_pairs: [('ц', 'о'), ('ло', 'сь'), ('зде', 'сь'), ('й', 'те'), ('серд', 'це'), ('лен', 'и'), ('т', 'вой'), ('е', 'шь'), ('о', 'ни'), ('те', 'перь')]
# max_pairs: [('де', 'ла'), ('ло', 'й'), ('з', 'е'), ('де', 'й'), ('д', 'ро'), ('хо', 'дит'), ('ит', 'ся'), ('е', 'сть'), ('ва', 'с'), ('ень', 'е')]
# max_pairs: [('ко', 'то'), ('т', 'ся'), ('о', 'д'), ('бу', 'дет'), ('до', 'ро'), ('ле', 'й'), ('ц', 'у'), ('бы', 'ло'), ('ве', 'ли'), ('н', 'ный')]
# max_pairs: [('пра', 'в'), ('т', 'ро'), ('со', 'л'), ('но', 'в'), ('в', 'ре'), ('и', 'ли'), ('ча', 'с'), ('ски', 'й'), ('ро', 'й'), ('по', 'сле')]
# max_pairs: [('но', 'е'), ('ж', 'ды'), ('са', 'м'), ('жиз', 'нь'), ('ст', 'вен'), ('мо', 'ло'), ('ка', 'ж'), ('ко', 'р'), ('ч', 'ен'), ('лу', 'ч')]
# max_pairs: [('п', 'ло'), ('ф', 'е'), ('з', 'у'), ('ни', 'х'), ('ска', 'за'), ('п', 'ет'), ('ше', 'л'), ('на', 'ш'), ('но', 'чь'), ('о', 'й')]
# max_pairs: [('бла', 'го'), ('ш', 'ен'), ('ь', 'я'), ('лю', 'би'), ('ни', 'ма'), ('и', 'с'), ('п', 'ь'), ('в', 'зо'), ('по', 'м'), ('с', 'па')]
# max_pairs: [('в', 'ме'), ('з', 'ло'), ('ду', 'ма'), ('ме', 'ж'), ('х', 'ра'), ('гово', 'ри'), ('на', 'до'), ('мо', 'жет'), ('ну', 'л'), ('и', 'н')]
# max_pairs: [('но', 'ю'), ('оди', 'н'), ('ду', 'ш'), ('то', 'л'), ('р', 'ю'), ('м', 'ра'), ('р', 'ен'), ('щи', 'й'), ('с', 'не'), ('ра', 'до')]
# max_pairs: [('че', 'ло'), ('е', 'в'), ('э', 'ти'), ('д', 'ня'), ('ки', 'х'), ('пере', 'д'), ('д', 'ре'), ('по', 'й'), ('ки', 'е'), ('сть', 'ю')]
# max_pairs: [('с', 'ре'), ('все', 'х'), ('н', 'ю'), ('у', 'же'), ('о', 'г'), ('сча', 'ст'), ('ите', 'ль'), ('а', 'р'), ('с', 'ни'), ('у', 'ста')]
# max_pairs: [('д', 'ва'), ('с', 'ен'), ('го', 'м'), ('го', 'ре'), ('мо', 'я'), ('ст', 'ва'), ('со', 'н'), ('то', 'т'), ('се', 'й'), ('п', 'ле')]
# max_pairs: [('д', 'ра'), ('ж', 'ит'), ('де', 'л'), ('к', 'ло'), ('з', 'ву'), ('вы', 'х'), ('ве', 'к'), ('а', 'л'), ('ст', 'ен'), ('к', 'ла')]
# max_pairs: [('я', 'сь'), ('пу', 'сть'), ('ка', 'я'), ('к', 'ри'), ('вс', 'ем'), ('ко', 'го'), ('с', 'пе'), ('та', 'й'), ('ду', 'т'), ('сло', 'ва')]
# max_pairs: [('любо', 'вь'), ('ве', 'се'), ('ры', 'й'), ('сть', 'я'), ('о', 'р'), ('гла', 'за'), ('сол', 'н'), ('ве', 'з'), ('я', 'в'), ('жиз', 'ни')]
# max_pairs: [('хо', 'д'), ('ч', 'ей'), ('сво', 'й'), ('ка', 'м'), ('д', 'ный'), ('бу', 'дь'), ('б', 'ре'), ('в', 'ста'), ('хо', 'ть'), ('ма', 'н')]
# max_pairs: [('да', 'л'), ('же', 'ла'), ('пя', 'ть'), ('не', 'е'), ('бо', 'ю'), ('бо', 'га'), ('п', 'ря'), ('те', 'ль'), ('е', 'з'), ('а', 'х')]
# max_pairs: [('с', 'ви'), ('ва', 'ет'), ('ло', 'м'), ('то', 'ва'), ('щ', 'ен'), ('ют', 'ся'), ('м', 'ного'), ('ко', 'не'), ('го', 'й'), ('ва', 'ри')]
# max_pairs: [('по', 'бе'), ('с', 'ем'), ('о', 'м'), ('да', 'ль'), ('д', 'во'), ('сво', 'бо'), ('м', 'ной'), ('то', 'в'), ('ж', 'ить'), ('мо', 'ей')]
# max_pairs: [('по', 'ка'), ('к', 'ли'), ('то', 'р'), ('ста', 'ри'), ('к', 'ля'), ('ски', 'х'), ('хо', 'ро'), ('ка', 'за'), ('ни', 'е'), ('на', 'де')]
# max_pairs: [('ш', 'ка'), ('то', 'го'), ('ка', 'х'), ('бы', 'ла'), ('бо', 'г'), ('ну', 'т'), ('в', 'друг'), ('зо', 'ло'), ('ва', 'ли'), ('щ', 'у')]
# max_pairs: [('сто', 'й'), ('ро', 'в'), ('жа', 'л'), ('ту', 'т'), ('су', 'дь'), ('в', 'ся'), ('вы', 'е'), ('по', 'р'), ('ве', 'сь'), ('ле', 'г')]
# max_pairs: [('ить', 'ся'), ('о', 'дно'), ('ну', 'ть'), ('д', 'ви'), ('это', 'т'), ('ку', 'да'), ('люб', 'ви'), ('воз', 'ь'), ('ва', 'н'), ('од', 'на')]
# max_pairs: [('да', 'ть'), ('не', 'го'), ('ца', 'рь'), ('з', 'я'), ('ж', 'де'), ('ко', 'ю'), ('зна', 'ю'), ('ш', 'ки'), ('ни', 'я'), ('в', 'то')]
# max_pairs: [('ст', 'ву'), ('у', 'да'), ('да', 'ли'), ('ми', 'ра'), ('е', 'ди'), ('мо', 'г'), ('ти', 'хо'), ('з', 'вез'), ('хо', 'ло'), ('то', 'гда')]
# max_pairs: [('ре', 'й'), ('ты', 'й'), ('ло', 'в'), ('да', 'вно'), ('ра', 'н'), ('ка', 'ми'), ('вме', 'сто'), ('ду', 'х'), ('ли', 'ца'), ('щ', 'их')]
# max_pairs: [('с', 'ве'), ('стра', 'н'), ('сту', 'п'), ('д', 'ли'), ('смо', 'три'), ('ч', 'ной'), ('ш', 'ей'), ('си', 'я'), ('мол', 'ча'), ('сно', 'ва')]
# max_pairs: [('во', 'ль'), ('ска', 'я'), ('го', 'в'), ('ки', 'м'), ('се', 'бя'), ('ст', 'но'), ('на', 'ми'), ('до', 'в'), ('во', 'ро'), ('ц', 'ен')]
# max_pairs: [('по', 'лу'), ('лы', 'е'), ('х', 'ва'), ('щ', 'ей'), ('и', 'л'), ('о', 'пять'), ('това', 'ри'), ('по', 'том'), ('то', 'бой'), ('сво', 'ей')]
# max_pairs: [('пу', 'ть'), ('не', 'бо'), ('кро', 'вь'), ('ч', 'ки'), ('ка', 'р'), ('ч', 'ный'), ('слу', 'ша'), ('все', 'гда'), ('мо', 'гу'), ('печа', 'ль')]
# max_pairs: [('ста', 'л'), ('ст', 'ру'), ('х', 'у'), ('вно', 'вь'), ('ро', 'к'), ('ле', 'з'), ('бер', 'е'), ('ны', 'ми'), ('бу', 'ду'), ('си', 'л')]
# max_pairs: [('ко', 'е'), ('по', 'ло'), ('об', 'ъ'), ('за', 'чем'), ('ри', 'т'), ('ча', 'й'), ('у', 'жа'), ('о', 'те'), ('мо', 'и'), ('ст', 'я')]
# max_pairs: [('з', 'ла'), ('сто', 'ро'), ('с', 'вер'), ('вер', 'ь'), ('вы', 'со'), ('не', 'с'), ('д', 'вер'), ('до', 'б'), ('во', 'д'), ('ж', 'ь')]
# max_pairs: [('де', 'м'), ('ру', 'ки'), ('счаст', 'ли'), ('не', 'ж'), ('да', 'ле'), ('ста', 'в'), ('ши', 'х'), ('стра', 'ш'), ('по', 'э'), ('ве', 'дь')]
# max_pairs: [('во', 'м'), ('на', 'ча'), ('лы', 'х'), ('кру', 'г'), ('ду', 'ша'), ('меч', 'та'), ('д', 'ней'), ('дит', 'е'), ('бы', 'ли'), ('ш', 'ли')]
# max_pairs: [('мо', 'ги'), ('я', 'н'), ('вс', 'ю'), ('вы', 'м'), ('дол', 'го'), ('во', 'сто'), ('у', 'лы'), ('мо', 'е'), ('хо', 'ди'), ('во', 'с')]
# max_pairs: [('бу', 'д'), ('ри', 'ф'), ('ск', 'ло'), ('пом', 'ни'), ('ш', 'ла'), ('се', 'бе'), ('б', 'ь'), ('ви', 'л'), ('взо', 'р'), ('о', 'ре')]
# max_pairs: [('г', 'ря'), ('мы', 'й'), ('вст', 'ре'), ('щ', 'ет'), ('ли', 'т'), ('ко', 'ль'), ('до', 'х'), ('не', 'бес'), ('да', 'же'), ('ды', 'й')]
# max_pairs: [('д', 'ной'), ('си', 'ль'), ('сло', 'в'), ('ро', 'ди'), ('ма', 'я'), ('з', 'во'), ('шу', 'м'), ('вз', 'гля'), ('го', 'ря'), ('да', 'й')]
# max_pairs: [('гру', 'дь'), ('смер', 'ть'), ('без', 'ум'), ('вре', 'мя'), ('ду', 'ши'), ('во', 'льно'), ('и', 'гра'), ('па', 'р'), ('м', 'г'), ('боль', 'ше')]
# max_pairs: [('ени', 'я'), ('пу', 'ска'), ('ле', 'к'), ('п', 'ит'), ('ски', 'е'), ('гла', 'з'), ('д', 'не'), ('ма', 'ть'), ('чит', 'а'), ('пре', 'крас')]
# max_pairs: [('в', 'ни'), ('сто', 'я'), ('б', 'ит'), ('не', 'бе'), ('ж', 'ден'), ('пу', 'сты'), ('об', 'ра'), ('п', 'ти'), ('г', 'не'), ('лю', 'ди')]
# max_pairs: [('ро', 'с'), ('чи', 'й'), ('ду', 'ше'), ('де', 'шь'), ('об', 'раз'), ('ско', 'го'), ('кра', 'со'), ('от', 'вет'), ('бу', 'р'), ('о', 'бо')]
# max_pairs: [('п', 'лен'), ('про', 'сто'), ('ве', 'ст'), ('ко', 'ло'), ('серд', 'ца'), ('мен', 'и'), ('лет', 'а'), ('но', 'чи'), ('жи', 'л'), ('мо', 'ю')]
# max_pairs: [('сла', 'д'), ('ка', 'кой'), ('ст', 'ер'), ('у', 'ви'), ('пе', 'с'), ('дет', 'ь'), ('солн', 'це'), ('от', 'ра'), ('оте', 'ц'), ('б', 'ен')]
# max_pairs: [('буд', 'то'), ('чу', 'вст'), ('ст', 'ви'), ('ва', 'р'), ('дру', 'з'), ('п', 'ен'), ('ца', 'р'), ('мо', 'р'), ('но', 'с'), ('сы', 'н')]
# max_pairs: [('з', 'ра'), ('голо', 'с'), ('ч', 'ка'), ('де', 'ли'), ('с', 'ю'), ('со', 'м'), ('об', 'ла'), ('ря', 'д'), ('да', 'м'), ('мер', 'т')]
# max_pairs: [('что', 'бы'), ('ти', 'ши'), ('ми', 'г'), ('т', 'ень'), ('лю', 'дей'), ('за', 'бы'), ('т', 'рет'), ('па', 'л'), ('ни', 'т'), ('ве', 'с')]
# max_pairs: [('пи', 'са'), ('мо', 'жно'), ('по', 'то'), ('по', 'ро'), ('де', 'ло'), ('коне', 'ц'), ('про', 'с'), ('ру', 'с'), ('ца', 'ри'), ('гро', 'м')]
# max_pairs: [('н', 'ной'), ('со', 'в'), ('ви', 'д'), ('у', 'т'), ('не', 'н'), ('у', 'би'), ('в', 'ъ'), ('му', 'ж'), ('мо', 'м'), ('у', 'зна')]
# max_pairs: [('да', 'р'), ('хо', 'те'), ('во', 'е'), ('жен', 'и'), ('п', 'ли'), ('х', 'ла'), ('жен', 'щи'), ('к', 'ни'), ('на', 'й'), ('го', 'ро')]
# max_pairs: [('хо', 'р'), ('га', 'м'), ('на', 'х'), ('после', 'дни'), ('т', 'ени'), ('ра', 'я'), ('ве', 'чер'), ('ня', 'т'), ('тво', 'ей'), ('у', 'вы')]
# max_pairs: [('да', 'ет'), ('гро', 'з'), ('щи', 'е'), ('лени', 'е'), ('мы', 'с'), ('каж', 'дый'), ('зем', 'ли'), ('ды', 'ха'), ('ж', 'ер'), ('хо', 'м')]
# max_pairs: [('сре', 'ди'), ('ши', 'й'), ('ну', 'в'), ('улы', 'б'), ('смер', 'т'), ('ст', 'ей'), ('ды', 'м'), ('ск', 'возь'), ('я', 'р'), ('бли', 'з')]
# max_pairs: [('от', 'кры'), ('сю', 'да'), ('ш', 'о'), ('нь', 'ем'), ('ш', 'ит'), ('ма', 'ло'), ('тво', 'и'), ('в', 'ле'), ('кото', 'ры'), ('ени', 'й')]
# max_pairs: [('кре', 'стья'), ('люб', 'лю'), ('ма', 'р'), ('бо', 'ги'), ('ди', 'шь'), ('с', 'му'), ('я', 'с'), ('си', 'ла'), ('сла', 'в'), ('ы', 'й')]
# max_pairs: [('го', 'спо'), ('г', 'на'), ('ве', 'чно'), ('зем', 'ле'), ('х', 'ле'), ('ф', 'о'), ('о', 'ч'), ('ко', 'ро'), ('лен', 'а'), ('вши', 'й')]
# max_pairs: [('ско', 'лько'), ('у', 'ме'), ('ли', 'цо'), ('бо', 'же'), ('сча', 'сть'), ('ни', 'н'), ('ми', 'л'), ('сказа', 'л'), ('л', 'ень'), ('по', 'ле')]
# max_pairs: [('по', 'ля'), ('ме', 'д'), ('ско', 'ро'), ('мо', 'ре'), ('ж', 'д'), ('ть', 'я'), ('и', 'сто'), ('сво', 'и'), ('та', 'я'), ('дет', 'и')]
# max_pairs: [('ди', 'в'), ('се', 'го'), ('ю', 'сь'), ('хо', 'т'), ('стари', 'к'), ('вши', 'сь'), ('ты', 'е'), ('ко', 'му'), ('и', 'дет'), ('п', 'ят')]
# max_pairs: [('меч', 'ты'), ('го', 'с'), ('луч', 'ше'), ('ви', 'жу'), ('ни', 'чего'), ('ско', 'р'), ('чело', 'век'), ('ет', 'ь'), ('ет', 'е'), ('п', 'раз')]
# max_pairs: [('ц', 'ем'), ('по', 'кой'), ('у', 'го'), ('бе', 'д'), ('стра', 'да'), ('та', 'н'), ('вз', 'я'), ('смер', 'ти'), ('мен', 'е'), ('ва', 'й')]
# max_pairs: [('ж', 'ный'), ('раз', 'ве'), ('по', 'ч'), ('чело', 'ве'), ('с', 'пи'), ('сво', 'ю'), ('ка', 'з'), ('тво', 'их'), ('жен', 'а'), ('ко', 'ле')]
# max_pairs: [('чу', 'ть'), ('по', 'з'), ('в', 'ит'), ('по', 'жа'), ('о', 'но'), ('о', 'го'), ('на', 'род'), ('но', 'сть'), ('тре', 'во'), ('ни', 'ка')]
# max_pairs: [('тя', 'же'), ('меж', 'ду'), ('сего', 'дня'), ('сло', 'во'), ('во', 'ло'), ('э', 'та'), ('на', 'ши'), ('дер', 'жа'), ('сто', 'ит'), ('тво', 'р')]
# max_pairs: [('не', 'ве'), ('ве', 'й'), ('ход', 'ят'), ('т', 'вер'), ('те', 'х'), ('по', 'мо'), ('а', 'д'), ('по', 'т'), ('у', 'те'), ('со', 'вет')]
# max_pairs: [('го', 'род'), ('ли', 'к'), ('у', 'мер'), ('хо', 'чу'), ('ми', 'ло'), ('п', 'лы'), ('сво', 'их'), ('з', 'ь'), ('гру', 'ди'), ('мо', 'их')]
# max_pairs: [('ра', 'б'), ('ск', 'ры'), ('дру', 'гой'), ('ва', 'ется'), ('са', 'ми'), ('ти', 'в'), ('ска', 'жи'), ('п', 'ля'), ('ря', 'т'), ('объ', 'я')]
# max_pairs: [('са', 'мо'), ('бо', 'р'), ('го', 'тов'), ('мо', 'н'), ('ль', 'я'), ('ство', 'м'), ('ени', 'е'), ('ни', 'ца'), ('сла', 'до'), ('т', 'ен')]
# max_pairs: [('сле', 'зы'), ('до', 'ма'), ('ми', 'ну'), ('сло', 'вно'), ('щи', 'м'), ('ва', 'ла'), ('ки', 'н'), ('глу', 'бо'), ('ви', 'н'), ('бла', 'жен')]
# max_pairs: [('слы', 'ша'), ('вет', 'ер'), ('на', 'п'), ('по', 'ра'), ('тво', 'я'), ('восто', 'р'), ('на', 'ро'), ('ла', 'й'), ('ч', 'ных'), ('тя', 'ж')]
# max_pairs: [('ду', 'м'), ('оре', 'ст'), ('бра', 'т'), ('ня', 'ть'), ('до', 'чь'), ('ми', 'лый'), ('чем', 'у'), ('дру', 'га'), ('ко', 'л'), ('ди', 'л')]
# max_pairs: [('м', 'ла'), ('ю', 'щий'), ('по', 'ве'), ('ла', 'я'), ('я', 'м'), ('то', 'е'), ('зем', 'лю'), ('ско', 'м'), ('ужа', 'с'), ('ни', 'будь')]
# max_pairs: [('б', 'ри'), ('ты', 'х'), ('счасть', 'е'), ('че', 'шь'), ('ма', 'тер'), ('ша', 'я'), ('это', 'й'), ('ф', 'ран'), ('да', 'в'), ('г', 'ер')]
# max_pairs: [('лен', 'ный'), ('при', 'вет'), ('ко', 'риф'), ('риф', 'ей'), ('сту', 'па'), ('ме', 'ль'), ('то', 'бою'), ('да', 'ми'), ('у', 'ны'), ('говори', 'т')]
# max_pairs: [('кориф', 'ей'), ('свет', 'е'), ('д', 'ят'), ('о', 'де'), ('нап', 'рас'), ('к', 'лю'), ('при', 'ро'), ('и', 'ска'), ('пер', 'вый'), ('до', 'бро')]
# max_pairs: [('радо', 'сть'), ('дет', 'ей'), ('ру', 'кой'), ('ш', 'но'), ('зо', 'р'), ('но', 'ги'), ('це', 'лу'), ('ги', 'е'), ('воз', 'вра'), ('не', 'на')]
# max_pairs: [('про', 'сти'), ('по', 'ги'), ('д', 'ву'), ('стро', 'й'), ('до', 'н'), ('яв', 'ление'), ('п', 'ита'), ('го', 'д'), ('м', 'ною'), ('ра', 'вно')]
# max_pairs: [('со', 'з'), ('ше', 'п'), ('ча', 'л'), ('о', 'жи'), ('но', 'си'), ('то', 'чно'), ('ст', 'ный'), ('о', 'дни'), ('пь', 'я'), ('свя', 'щен')]
# max_pairs: [('ни', 'ки'), ('жа', 'ло'), ('кро', 'ва'), ('ми', 'на'), ('п', 'ру'), ('ни', 'ми'), ('го', 'рь'), ('чи', 'к'), ('то', 'к'), ('ва', 'ми')]
# max_pairs: [('с', 'дела'), ('ду', 'шу'), ('мен', 'а'), ('мо', 'ли'), ('ву', 'ю'), ('ше', 'го'), ('го', 'лу'), ('па', 'ла'), ('та', 'кой'), ('и', 'спо')]
# max_pairs: [('о', 'чи'), ('но', 'сти'), ('кро', 'ви'), ('ту', 'да'), ('ва', 'ют'), ('ле', 'с'), ('ни', 'и'), ('ту', 'ма'), ('ру', 'ку'), ('стро', 'фа')]
# max_pairs: [('до', 'ж'), ('о', 'ча'), ('э', 'ту'), ('ну', 'лся'), ('сказа', 'ть'), ('но', 'ж'), ('в', 'нима'), ('но', 'вен'), ('про', 'кля'), ('е', 'ц')]
# max_pairs: [('ш', 'ло'), ('и', 'ме'), ('ди', 'м'), ('не', 'счаст'), ('зем', 'ля'), ('ны', 'не'), ('это', 'м'), ('цо', 'в'), ('ск', 'е'), ('з', 'ме')]
# max_pairs: [('ня', 'л'), ('от', 'да'), ('пу', 'сти'), ('с', 'ъ'), ('сво', 'е'), ('ра', 'д'), ('да', 'н'), ('ан', 'ти'), ('б', 'ря'), ('ла', 'м')]
# max_pairs: [('спо', 'кой'), ('мы', 'сли'), ('оч', 'ень'), ('чер', 'ез'), ('му', 'ч'), ('к', 'ня'), ('ца', 'ть'), ('о', 'бе'), ('ну', 'ла'), ('я', 'х')]
# max_pairs: [('ка', 'н'), ('по', 'ли'), ('зе', 'лен'), ('то', 'н'), ('лы', 'м'), ('ж', 'ем'), ('за', 'бо'), ('г', 'ли'), ('ро', 'ко'), ('да', 'я')]
# max_pairs: [('ра', 'в'), ('во', 'ю'), ('кру', 'гом'), ('сле', 'з'), ('о', 'в'), ('ст', 'ры'), ('товари', 'щ'), ('я', 'зы'), ('и', 'ску'), ('г', 'ри')]
# max_pairs: [('друз', 'ья'), ('ц', 'ей'), ('за', 'ка'), ('пре', 'жде'), ('не', 'му'), ('го', 'то'), ('вши', 'х'), ('сто', 'л'), ('ж', 'ду'), ('ги', 'м')]
# max_pairs: [('ре', 'чь'), ('ре', 'з'), ('пре', 'ж'), ('ви', 'дел'), ('ча', 'я'), ('ст', 'ве'), ('ль', 'ный'), ('до', 'ю'), ('ите', 'льно'), ('э', 'лек')]
# max_pairs: [('дро', 'жа'), ('е', 'два'), ('де', 'ся'), ('ни', 'ть'), ('но', 'к'), ('у', 'ч'), ('ку', 'ю'), ('би', 'ра'), ('про', 'ща'), ('чи', 'сты')]
# max_pairs: [('бе', 'га'), ('це', 'в'), ('те', 'к'), ('о', 'ю'), ('й', 'ся'), ('па', 'ри'), ('рабо', 'та'), ('ни', 'цы'), ('ми', 'ре'), ('кра', 'й')]
# max_pairs: [('т', 'ит'), ('последни', 'й'), ('ж', 'день'), ('ят', 'ся'), ('д', 'ве'), ('люби', 'л'), ('со', 'бой'), ('но', 'г'), ('су', 'т'), ('ва', 'ло')]
# max_pairs: [('из', 'ве'), ('ни', 'кто'), ('нь', 'ю'), ('ск', 'ре'), ('не', 'до'), ('дет', 'е'), ('ого', 'нь'), ('пла', 'ка'), ('и', 'й'), ('об', 'ма')]
# max_pairs: [('д', 'на'), ('пи', 'л'), ('на', 'конец'), ('кото', 'рый'), ('не', 'по'), ('о', 'ко'), ('дво', 'р'), ('по', 'ки'), ('ре', 'ц'), ('пра', 'во')]
# max_pairs: [('ски', 'м'), ('у', 'г'), ('од', 'ной'), ('ни', 'л'), ('по', 'ль'), ('чу', 'ж'), ('кра', 'са'), ('вол', 'ны'), ('ва', 'ш'), ('то', 'му')]
# max_pairs: [('сле', 'за'), ('же', 'шь'), ('за', 'б'), ('при', 'зра'), ('му', 'зы'), ('кор', 'ми'), ('вме', 'сте'), ('и', 'д'), ('хо', 'зя'), ('па', 'н')]
# max_pairs: [('хо', 'чешь'), ('ш', 'ку'), ('лет', 'е'), ('га', 'ми'), ('дит', 'я'), ('ё', 'т'), ('сей', 'час'), ('ле', 'е'), ('ме', 'ся'), ('ж', 'ной')]
# max_pairs: [('ра', 'к'), ('ста', 'ли'), ('ско', 'ль'), ('это', 'го'), ('чи', 'л'), ('ст', 'ит'), ('по', 'ко'), ('но', 'му'), ('ско', 'рей'), ('ну', 'ли')]
# max_pairs: [('бо', 'ро'), ('люб', 'ить'), ('же', 'сто'), ('с', 'цен'), ('с', 'са'), ('зна', 'ко'), ('л', 'ла'), ('по', 'кры'), ('сем', 'ь'), ('до', 'вольно')]
# max_pairs: [('хо', 'в'), ('свет', 'а'), ('х', 'ри'), ('тру', 'д'), ('хо', 'чет'), ('щ', 'его'), ('ча', 'т'), ('коне', 'чно'), ('пуска', 'й'), ('и', 'ду')]
# max_pairs: [('за', 'в'), ('жер', 'т'), ('сер', 'е'), ('ан', 'ге'), ('ль', 'ю'), ('ру', 'ка'), ('ре', 'в'), ('из', 'мен'), ('ень', 'ем'), ('о', 'па')]
# max_pairs: [('зна', 'ть'), ('ву', 'т'), ('жа', 'р'), ('со', 'ю'), ('ве', 'л'), ('кре', 'п'), ('в', 'ку'), ('ско', 'е'), ('тре', 'пет'), ('пу', 'ти')]
# max_pairs: [('о', 'с'), ('зо', 'в'), ('гра', 'жда'), ('по', 'ры'), ('душ', 'ой'), ('ч', 'ные'), ('т', 'но'), ('ти', 'л'), ('ши', 'м'), ('т', 'ка')]
# max_pairs: [('су', 'д'), ('ци', 'и'), ('не', 'шь'), ('во', 'ды'), ('дума', 'л'), ('не', 'ц'), ('а', 'м'), ('з', 'вер'), ('ч', 'ку'), ('ма', 'ши')]
# max_pairs: [('в', 'перед'), ('тор', 'же'), ('щ', 'ит'), ('мо', 'ск'), ('ты', 'ся'), ('ста', 'ро'), ('хоте', 'л'), ('су', 'ро'), ('у', 'й'), ('рабо', 'чи')]
# max_pairs: [('двер', 'ь'), ('мы', 'х'), ('со', 'гла'), ('ска', 'з'), ('у', 'кра'), ('п', 'лю'), ('сре', 'дь'), ('дол', 'жен'), ('го', 'ра'), ('жен', 'ы')]
# max_pairs: [('па', 'мя'), ('н', 'ки'), ('хоро', 'шо'), ('ли', 'ся'), ('де', 'ви'), ('нет', 'ся'), ('ве', 'ц'), ('гро', 'б'), ('эти', 'х'), ('и', 'мя')]
# max_pairs: [('напрас', 'но'), ('ту', 'ман'), ('трет', 'ь'), ('ре', 'чи'), ('у', 'з'), ('сле', 'д'), ('пе', 'сни'), ('ж', 'ите'), ('пре', 'ле'), ('пла', 'мен')]
# max_pairs: [('ис', 'че'), ('за', 'н'), ('во', 'н'), ('н', 'ных'), ('во', 'го'), ('п', 'лет'), ('сча', 'стья'), ('ви', 'но'), ('стре', 'м'), ('но', 'вый')]
# max_pairs: [('со', 'й'), ('мра', 'к'), ('жа', 'ть'), ('в', 'ка'), ('ма', 'ль'), ('по', 'кор'), ('сво', 'им'), ('сча', 'сти'), ('ни', 'когда'), ('го', 'да')]
# max_pairs: [('во', 'лю'), ('пи', 'сь'), ('про', 'тив'), ('дол', 'ж'), ('спа', 'с'), ('бе', 'ль'), ('у', 'тра'), ('не', 'ль'), ('ча', 'сто'), ('за', 'па')]
# max_pairs: [('стра', 'сти'), ('м', 'ень'), ('ш', 'ком'), ('слу', 'чай'), ('до', 'ли'), ('ща', 'я'), ('ко', 'с'), ('га', 'л'), ('ст', 'ной'), ('дит', 'ся')]
# max_pairs: [('ночь', 'ю'), ('цо', 'м'), ('го', 'рит'), ('пра', 'х'), ('ды', 'ша'), ('мене', 'лай'), ('за', 'ви'), ('о', 'ру'), ('ца', 'ря'), ('га', 'с')]
# max_pairs: [('чу', 'т'), ('ти', 'х'), ('бо', 'рь'), ('ни', 'ков'), ('чер', 'то'), ('по', 'рой'), ('щ', 'ем'), ('бо', 'я'), ('со', 'р'), ('дре', 'в')]
# max_pairs: [('печа', 'ли'), ('с', 'ны'), ('то', 'же'), ('ва', 'ю'), ('та', 'ин'), ('дру', 'го'), ('з', 'ри'), ('не', 'ю'), ('со', 'всем'), ('пе', 'л')]
# max_pairs: [('ком', 'му'), ('т', 'ить'), ('пе', 'ли'), ('тво', 'е'), ('чи', 'на'), ('т', 'ю'), ('з', 'ер'), ('н', 'т'), ('ста', 'р'), ('прав', 'да')]
# max_pairs: [('от', 'ве'), ('лю', 'без'), ('ска', 'жу'), ('те', 'ло'), ('поэ', 'т'), ('бу', 'дешь'), ('хо', 'тя'), ('па', 'ль'), ('каж', 'ется'), ('му', 'жи')]
# max_pairs: [('при', 'вы'), ('ра', 'м'), ('сто', 'м'), ('во', 'круг'), ('ру', 'к'), ('ро', 'з'), ('дни', 'к'), ('ф', 'ор'), ('зна', 'ет'), ('по', 'до')]
# max_pairs: [('про', 'во'), ('лен', 'ной'), ('т', 'ки'), ('бо', 'м'), ('госпо', 'ди'), ('серд', 'цу'), ('раз', 'у'), ('от', 'ца'), ('не', 'жно'), ('товари', 'щи')]
# max_pairs: [('ча', 'ть'), ('ма', 'х'), ('вы', 'ше'), ('нь', 'и'), ('е', 'лена'), ('зна', 'л'), ('лу', 'на'), ('с', 'пу'), ('вст', 'рет'), ('э', 'й')]
# max_pairs: [('бур', 'жу'), ('ва', 'ться'), ('з', 'ет'), ('испо', 'л'), ('цвет', 'ы'), ('воз', 'дух'), ('ло', 'б'), ('во', 'ли'), ('чу', 'де'), ('пи', 'ла')]
# max_pairs: [('у', 'са'), ('яв', 'ля'), ('без', 'мол'), ('по', 'ме'), ('гово', 'р'), ('за', 'ли'), ('за', 'д'), ('ми', 'мо'), ('у', 'ходит'), ('ге', 'ро')]
# max_pairs: [('нель', 'зя'), ('жа', 'ль'), ('о', 'бы'), ('д', 'ные'), ('под', 'ру'), ('дол', 'жно'), ('мя', 'те'), ('та', 'л'), ('у', 'мира'), ('ви', 'дит')]
# max_pairs: [('бро', 'са'), ('ста', 'рый'), ('ску', 'ю'), ('ни', 'что'), ('че', 'сть'), ('ды', 'ма'), ('г', 'ло'), ('мо', 'ря'), ('б', 'лю'), ('ве', 'сть')]
# max_pairs: [('зво', 'н'), ('пол', 'но'), ('смо', 'т'), ('же', 'л'), ('жи', 'в'), ('с', 'на'), ('за', 'кры'), ('че', 'к'), ('всю', 'ду'), ('по', 'вер')]
# max_pairs: [('дву', 'х'), ('матер', 'и'), ('ре', 'ш'), ('под', 'ня'), ('г', 'ну'), ('в', 'до'), ('стра', 'х'), ('жи', 'й'), ('бе', 'ло'), ('ж', 'дет')]
# max_pairs: [('ю', 'щих'), ('ста', 'ла'), ('ти', 'я'), ('ро', 'ме'), ('са', 'ма'), ('де', 'я'), ('ви', 'дно'), ('об', 'а'), ('при', 'дет'), ('ы', 'х')]
# max_pairs: [('солн', 'ца'), ('ста', 'ло'), ('жи', 'вет'), ('тер', 'я'), ('я', 'ви'), ('п', 'ей'), ('пре', 'да'), ('иску', 'с'), ('а', 'ль'), ('ю', 'но')]
# max_pairs: [('д', 'ных'), ('ра', 'бы'), ('ствен', 'ный'), ('глу', 'би'), ('ши', 'е'), ('у', 'ли'), ('раз', 'ли'), ('мо', 'ль'), ('бле', 'ск'), ('сти', 'х')]
# max_pairs: [('те', 'ле'), ('счастли', 'в'), ('ра', 'й'), ('ха', 'л'), ('ж', 'ре'), ('вер', 'но'), ('по', 'доб'), ('вен', 'ча'), ('дер', 'ев'), ('сер', 'де')]
# max_pairs: [('ра', 'ми'), ('и', 'шь'), ('за', 'кон'), ('голо', 'ву'), ('и', 'сти'), ('до', 'мой'), ('к', 'ну'), ('пом', 'ню'), ('кри', 'к'), ('па', 'ли')]
# max_pairs: [('двер', 'и'), ('бу', 'й'), ('бо', 'гов'), ('но', 'ви'), ('ал', 'та'), ('ст', 'в'), ('ло', 'же'), ('стви', 'е'), ('на', 'у'), ('по', 'да')]
# max_pairs: [('му', 'ки'), ('про', 'й'), ('ста', 'н'), ('жи', 'ли'), ('роме', 'о'), ('дер', 'з'), ('чь', 'я'), ('го', 'ды'), ('хо', 'л'), ('бы', 'стро')]
# max_pairs: [('уби', 'й'), ('ро', 'т'), ('все', 'й'), ('ве', 'ща'), ('п', 'ить'), ('вре', 'мен'), ('не', 'у'), ('де', 'ва'), ('ва', 'лся'), ('ле', 'жит')]
# max_pairs: [('гово', 'рят'), ('ста', 'ру'), ('на', 'сла'), ('ни', 'те'), ('со', 'к'), ('вол', 'ше'), ('си', 'м'), ('ста', 'я'), ('на', 'зад'), ('ня', 'я')]
# max_pairs: [('рос', 'си'), ('чет', 'ы'), ('чит', 'ся'), ('волше', 'б'), ('б', 'ить'), ('де', 'в'), ('че', 'ра'), ('т', 'ный'), ('дру', 'ж'), ('х', 'ит')]
# max_pairs: [('в', 'ли'), ('и', 'на'), ('не', 'ба'), ('за', 'м'), ('да', 'ла'), ('гля', 'дит'), ('ка', 'кая'), ('ко', 'ва'), ('моло', 'дой'), ('ла', 'ска')]
# max_pairs: [('под', 'ви'), ('и', 'но'), ('вра', 'г'), ('де', 'ль'), ('чер', 'е'), ('ви', 'дишь'), ('д', 'р'), ('тем', 'но'), ('хо', 'й'), ('кар', 'ти')]
# max_pairs: [('вс', 'кий'), ('зав', 'тра'), ('ши', 'л'), ('гос', 'под'), ('ты', 'м'), ('те', 'мне'), ('зо', 'й'), ('си', 'лы'), ('с', 'ра'), ('га', 'х')]
# max_pairs: [('ц', 'ер'), ('мил', 'ли'), ('корми', 'лица'), ('во', 'спо'), ('си', 'ли'), ('взгля', 'д'), ('ре', 'м'), ('бе', 'гу'), ('з', 'ва'), ('сти', 'хи')]
# max_pairs: [('о', 'за'), ('л', 'енья'), ('со', 'бра'), ('се', 'л'), ('и', 'дут'), ('об', 'и'), ('ча', 'ет'), ('да', 'ром'), ('ё', 'м'), ('ла', 'ся')]
# max_pairs: [('со', 'б'), ('м', 'ят'), ('пря', 'мо'), ('ве', 'зде'), ('ог', 'ня'), ('ста', 'нет'), ('зву', 'к'), ('ль', 'ет'), ('би', 'й'), ('ра', 'ду')]
# max_pairs: [('ни', 'з'), ('ши', 'ро'), ('тво', 'ю'), ('в', 'дох'), ('бе', 'жит'), ('ф', 'у'), ('все', 'го'), ('са', 'х'), ('де', 'ву'), ('ре', 'ль')]
# max_pairs: [('ри', 'л'), ('смотри', 'т'), ('сла', 'ва'), ('судь', 'ба'), ('с', 'ет'), ('з', 'вен'), ('ре', 'д'), ('а', 'т'), ('чу', 'в'), ('ы', 'е')]
# max_pairs: [('за', 'ко'), ('ба', 'р'), ('з', 'ной'), ('мы', 'е'), ('во', 'скре'), ('ги', 'й'), ('те', 'й'), ('мыс', 'ль'), ('в', 'не'), ('бу', 'дут')]
# max_pairs: [('о', 'ра'), ('поги', 'б'), ('ше', 'к'), ('щи', 'к'), ('зна', 'чит'), ('мо', 'лит'), ('зву', 'ки'), ('ци', 'я'), ('до', 'к'), ('к', 'си')]
# max_pairs: [('ри', 'ть'), ('пы', 'ла'), ('даль', 'ше'), ('лег', 'ко'), ('к', 'ле'), ('га', 'я'), ('при', 'шел'), ('уг', 'рю'), ('ч', 'ным'), ('из', 'гна')]
# max_pairs: [('лен', 'но'), ('цари', 'ца'), ('лет', 'ит'), ('ро', 'б'), ('вла', 'сть'), ('ч', 'ить'), ('дела', 'ть'), ('ря', 'дом'), ('ск', 'ри'), ('смо', 'тре')]
# max_pairs: [('гла', 'с'), ('ж', 'ных'), ('друз', 'ей'), ('звез', 'ды'), ('на', 'ша'), ('ру', 'ках'), ('ля', 'ет'), ('ве', 'сти'), ('йте', 'сь'), ('ве', 'ка')]
# max_pairs: [('то', 'ю'), ('по', 'целу'), ('страш', 'но'), ('за', 'л'), ('вол', 'не'), ('су', 'да'), ('ли', 'н'), ('на', 'ших'), ('ог', 'не'), ('д', 'ря')]
# max_pairs: [('с', 'пит'), ('ше', 'д'), ('раз', 'лу'), ('кровь', 'ю'), ('наш', 'ей'), ('гор', 'до'), ('ро', 'н'), ('он', 'т'), ('мо', 'в'), ('дер', 'е')]
# max_pairs: [('то', 'ми'), ('ви', 'деть'), ('г', 'ен'), ('оди', 'но'), ('по', 'сла'), ('ни', 'ц'), ('ще', 'е'), ('лу', 'й'), ('пе', 'в'), ('но', 'вой')]
# max_pairs: [('пото', 'му'), ('а', 'фи'), ('по', 'нима'), ('во', 'ле'), ('сы', 'на'), ('сто', 'в'), ('и', 'о'), ('голо', 'вой'), ('ста', 'ра'), ('оста', 'в')]
# max_pairs: [('вши', 'е'), ('те', 'льно'), ('при', 'зна'), ('раз', 'ру'), ('си', 'лен'), ('дно', 'го'), ('за', 'ре'), ('да', 'х'), ('би', 'л'), ('за', 'ба')]
# max_pairs: [('бу', 'дем'), ('любовь', 'ю'), ('у', 'ча'), ('хо', 'дя'), ('то', 'ской'), ('жда', 'л'), ('бу', 'ма'), ('и', 'фи'), ('элек', 'тра'), ('ско', 'ре')]
# max_pairs: [('которы', 'е'), ('ну', 'жно'), ('х', 'ло'), ('по', 'сте'), ('н', 'ные'), ('н', 'ка'), ('я', 'сно'), ('эти', 'м'), ('ля', 'ть'), ('чи', 'м')]
# max_pairs: [('гу', 'б'), ('це', 'лый'), ('кре', 'ст'), ('п', 'ры'), ('а', 'в'), ('меся', 'ц'), ('жда', 'ть'), ('с', 'пра'), ('за', 'мет'), ('свер', 'ка')]
# max_pairs: [('кро', 'в'), ('ти', 'хи'), ('ль', 'е'), ('хле', 'б'), ('ле', 'м'), ('ифи', 'г'), ('хра', 'ни'), ('жу', 'р'), ('бы', 'вало'), ('ли', 'ст')]
# max_pairs: [('ме', 'сто'), ('ре', 'бен'), ('ч', 'ная'), ('мо', 'им'), ('при', 'ят'), ('в', 'дали'), ('жи', 'м'), ('пет', 'ь'), ('кто', 'р'), ('у', 'па')]
# max_pairs: [('жен', 'ный'), ('дале', 'ко'), ('женщи', 'на'), ('с', 'мир'), ('за', 'то'), ('про', 'чь'), ('у', 'по'), ('чу', 'до'), ('рабо', 'чий'), ('ско', 'ю')]
# max_pairs: [('ид', 'ти'), ('ры', 'х'), ('ри', 'н'), ('ф', 'ей'), ('же', 'лез'), ('люб', 'ит'), ('сла', 'вы'), ('шь', 'ся'), ('дре', 'м'), ('щ', 'ь')]
# max_pairs: [('дви', 'ж'), ('ла', 'н'), ('слад', 'ко'), ('ды', 'х'), ('со', 'ло'), ('ни', 'ем'), ('же', 'й'), ('со', 'мне'), ('ри', 'м'), ('ра', 'ди')]
# max_pairs: [('ро', 'жден'), ('и', 'ной'), ('во', 'ж'), ('па', 'у'), ('вста', 'вка'), ('по', 'кло'), ('по', 'па'), ('у', 'с'), ('ле', 'д'), ('с', 'с')]
# max_pairs: [('ну', 'сь'), ('кры', 'ла'), ('не', 'ме'), ('ше', 'е'), ('ра', 'ба'), ('чет', 'вер'), ('соз', 'да'), ('по', 'ю'), ('г', 'ры'), ('холо', 'д')]
# max_pairs: [('ти', 'й'), ('са', 'д'), ('ло', 'ша'), ('а', 'на'), ('щ', 'ер'), ('б', 'лу'), ('пре', 'з'), ('стра', 'сть'), ('л', 'ё'), ('вла', 'ды')]
# max_pairs: [('кон', 'ца'), ('воз', 'можно'), ('со', 'вер'), ('ны', 'н'), ('дру', 'гу'), ('тиши', 'не'), ('ро', 'ма'), ('вест', 'ник'), ('ва', 'к'), ('у', 'спе')]
# max_pairs: [('па', 'ра'), ('раз', 'ум'), ('ду', 'ю'), ('свя', 'той'), ('мо', 'на'), ('вая', 'сь'), ('в', 'ходит'), ('хра', 'м'), ('си', 'дит'), ('пу', 'га')]
# max_pairs: [('ш', 'ет'), ('но', 'во'), ('по', 'ща'), ('бес', 'пе'), ('пи', 'р'), ('воспо', 'мина'), ('сти', 'ха'), ('че', 'л'), ('ко', 'нь'), ('ре', 'пли')]
# max_pairs: [('за', 'р'), ('кра', 'си'), ('язы', 'к'), ('памя', 'ть'), ('ст', 'ите'), ('л', 'енье'), ('друг', 'их'), ('сли', 'шком'), ('улыб', 'кой'), ('н', 'но')]
# max_pairs: [('за', 'ж'), ('дно', 'е'), ('х', 'во'), ('стен', 'ы'), ('сме', 'х'), ('пре', 'до'), ('до', 'ста'), ('са', 'н'), ('ча', 'ми'), ('за', 'вет')]
# max_pairs: [('ле', 'жа'), ('слы', 'шу'), ('ба', 'ш'), ('ча', 'сы'), ('фран', 'цу'), ('говори', 'л'), ('в', 'ный'), ('му', 'т'), ('при', 'зы'), ('ог', 'нем')]
# max_pairs: [('д', 'нем'), ('бо', 'гу'), ('радо', 'сти'), ('тво', 'им'), ('ству', 'ет'), ('бе', 'й'), ('д', 'цать'), ('пра', 'ви'), ('га', 'на'), ('ви', 'день')]
# max_pairs: [('гу', 'л'), ('ли', 'й'), ('се', 'я'), ('и', 'ва'), ('е', 'ли'), ('ифиг', 'ения'), ('ко', 'лы'), ('му', 'д'), ('вз', 'дох'), ('пес', 'ня')]
# max_pairs: [('у', 'ма'), ('бо', 'к'), ('су', 'ет'), ('лю', 'д'), ('весе', 'ло'), ('да', 'ют'), ('сто', 'лет'), ('м', 'ит'), ('с', 'чита'), ('со', 'ба')]
# max_pairs: [('зо', 'вет'), ('сы', 'па'), ('це', 'ли'), ('к', 'лу'), ('за', 'быть'), ('та', 'ми'), ('з', 'дра'), ('су', 'жден'), ('кра', 'т'), ('по', 'зор')]
# max_pairs: [('чь', 'и'), ('ф', 'ы'), ('нача', 'ла'), ('щу', 'т'), ('бере', 'г'), ('по', 'вто'), ('анге', 'л'), ('ту', 'ю'), ('а', 'ли'), ('род', 'ной')]
# max_pairs: [('ся', 'т'), ('бес', 'смерт'), ('ра', 'х'), ('со', 'бою'), ('но', 'чной'), ('сто', 'н'), ('от', 'вер'), ('ка', 'л'), ('о', 'то'), ('и', 'ди')]
# max_pairs: [('нын', 'че'), ('ка', 'кие'), ('ме', 'ста'), ('го', 'ры'), ('краса', 'ви'), ('ра', 'ст'), ('гре', 'ш'), ('от', 'ч'), ('та', 'х'), ('ко', 'ня')]
# max_pairs: [('пу', 'сто'), ('вен', 'ец'), ('сты', 'й'), ('лу', 'ю'), ('с', 'ва'), ('наде', 'жды'), ('пре', 'ступ'), ('вла', 'сти'), ('ро', 'зо'), ('про', 'бу')]
# max_pairs: [('жи', 'ла'), ('ю', 'щей'), ('ло', 'н'), ('га', 'зет'), ('ем', 'но'), ('и', 'ла'), ('ень', 'ю'), ('ла', 'зу'), ('ка', 'ра'), ('и', 'ю')]
# max_pairs: [('призра', 'к'), ('се', 'д'), ('об', 'ли'), ('з', 'доро'), ('кре', 'онт'), ('зем', 'ной'), ('ле', 'л'), ('зна', 'ешь'), ('ме', 'л'), ('де', 'вы')]
# max_pairs: [('жре', 'бий'), ('ге', 'ку'), ('во', 'да'), ('скло', 'ня'), ('ну', 'ж'), ('ви', 'на'), ('ф', 'ер'), ('д', 'ить'), ('отч', 'из'), ('от', 'чего')]
# max_pairs: [('лю', 'сь'), ('ри', 'я'), ('пожа', 'луй'), ('а', 'гам'), ('гам', 'емно'), ('лу', 'ка'), ('ду', 'мы'), ('ло', 'г'), ('раз', 'да'), ('оста', 'вь')]
# max_pairs: [('агам', 'емно'), ('до', 'го'), ('си', 'нь'), ('таин', 'ствен'), ('сме', 'я'), ('ви', 'ли'), ('лу', 'чи'), ('на', 'ше'), ('серд', 'цем'), ('ра', 'л')]
# max_pairs: [('про', 'зра'), ('про', 'из'), ('при', 'мер'), ('га', 'ет'), ('до', 'бы'), ('го', 'сти'), ('су', 'пру'), ('ча', 'х'), ('с', 'про'), ('чув', 'ство')]
# max_pairs: [('жи', 'вой'), ('от', 'куда'), ('мг', 'ле'), ('мо', 'гла'), ('де', 'мон'), ('хозя', 'й'), ('ск', 'ром'), ('в', 'вер'), ('кла', 'д'), ('та', 'кое')]
# max_pairs: [('о', 'стро'), ('з', 'ре'), ('над', 'мен'), ('пы', 'т'), ('а', 'к'), ('ходи', 'л'), ('ку', 'р'), ('под', 'нима'), ('о', 'ке'), ('цвет', 'а')]
# max_pairs: [('з', 'лой'), ('побе', 'до'), ('ша', 'т'), ('ок', 'но'), ('ту', 'чи'), ('за', 'п'), ('бе', 'жа'), ('д', 'ри'), ('те', 'сь'), ('су', 'мра')]
# max_pairs: [('ту', 'р'), ('о', 'кон'), ('жи', 'во'), ('у', 'ст'), ('бо', 'го'), ('чуде', 'с'), ('ст', 'ных'), ('гря', 'ду'), ('ми', 'нут'), ('в', 'круг')]
# max_pairs: [('ло', 'к'), ('о', 'кру'), ('я', 'д'), ('на', 'ве'), ('по', 'ет'), ('бе', 'дный'), ('о', 'чей'), ('вс', 'помни'), ('це', 'ло'), ('ды', 'е')]
# max_pairs: [('скло', 'ни'), ('слуша', 'й'), ('под', 'ъ'), ('в', 'чера'), ('си', 'не'), ('душ', 'ою'), ('ра', 'нь'), ('та', 'кие'), ('в', 'ну'), ('по', 'слуша')]
# max_pairs: [('по', 'ста'), ('дру', 'гие'), ('не', 'из'), ('ле', 'ц'), ('благо', 'да'), ('мя', 'г'), ('дь', 'я'), ('бе', 'г'), ('од', 'ну'), ('дер', 'жи')]
# max_pairs: [('тол', 'па'), ('ст', 'ить'), ('по', 'сти'), ('ч', 'ном'), ('ч', 'ного'), ('ро', 'ва'), ('о', 'со'), ('ме', 'й'), ('кам', 'ень'), ('сме', 'ло')]
# max_pairs: [('ль', 'ной'), ('кня', 'зь'), ('по', 'ту'), ('тол', 'пой'), ('пы', 'ш'), ('стра', 'стей'), ('га', 'р'), ('моло', 'д'), ('тра', 'к'), ('ш', 'ко')]
# max_pairs: [('ч', 'ке'), ('гра', 'ни'), ('н', 'ная'), ('а', 'вто'), ('итель', 'ный'), ('ча', 'ли'), ('до', 'чер'), ('го', 'сть'), ('ро', 'е'), ('ди', 'ли')]
# max_pairs: [('четы', 'ре'), ('анти', 'строфа'), ('скоре', 'е'), ('сне', 'г'), ('чи', 'е'), ('на', 'век'), ('с', 'ном'), ('ва', 'ши'), ('вер', 'ный'), ('ж', 'гу')]
# max_pairs: [('как', 'ъ'), ('вол', 'ну'), ('бога', 'т'), ('за', 'ря'), ('ре', 'ши'), ('воро', 'т'), ('пла', 'мя'), ('свобо', 'ды'), ('ла', 'ско'), ('ите', 'сь')]
# max_pairs: [('красо', 'ты'), ('доро', 'ги'), ('челове', 'ка'), ('одна', 'ко'), ('судь', 'бы'), ('по', 'чему'), ('ска', 'жет'), ('у', 'див'), ('ени', 'ем'), ('в', 'нем')]
# max_pairs: [('ца', 'рев'), ('крестья', 'н'), ('победо', 'носи'), ('к', 'ъ'), ('во', 'дит'), ('ца', 'м'), ('неж', 'ный'), ('лени', 'я'), ('пло', 'ща'), ('ну', 'лась')]
# max_pairs: [('зо', 'м'), ('а', 'й'), ('каза', 'лось'), ('исче', 'з'), ('с', 'мы'), ('мг', 'новен'), ('вь', 'я'), ('крас', 'но'), ('на', 'гра'), ('ста', 'ть')]
# max_pairs: [('у', 'ю'), ('ко', 'вар'), ('не', 'вин'), ('вер', 'ши'), ('по', 'хо'), ('после', 'д'), ('бли', 'же'), ('ле', 'са'), ('ва', 'х'), ('о', 'сен')]
# max_pairs: [('мо', 'его'), ('щу', 'ю'), ('сою', 'з'), ('ар', 'гос'), ('та', 'ких'), ('ша', 'г'), ('нос', 'ит'), ('лен', 'ы'), ('лю', 'бя'), ('по', 'в')]
# max_pairs: [('си', 'лой'), ('ш', 'ить'), ('ля', 'т'), ('вь', 'ю'), ('поч', 'ти'), ('лен', 'ных'), ('у', 'ми'), ('ге', 'рак'), ('до', 'р'), ('тихи', 'й')]
# max_pairs: [('ки', 'ми'), ('про', 'ро'), ('ждень', 'я'), ('ру', 'ками'), ('ла', 'ни'), ('е', 'ю'), ('ж', 'дой'), ('бе', 'лый'), ('и', 'мен'), ('приро', 'ды')]
# max_pairs: [('гу', 'бы'), ('ка', 'пу'), ('те', 'сей'), ('за', 'ть'), ('гне', 'в'), ('уда', 'р'), ('ско', 'му'), ('д', 'ным'), ('рань', 'ше'), ('ю', 'щие')]
# max_pairs: [('ри', 'й'), ('геку', 'ба'), ('по', 'мина'), ('ен', 'ный'), ('мы', 'ш'), ('ве', 'ль'), ('чи', 'сто'), ('ени', 'и'), ('к', 'ем'), ('с', 'в')]
# max_pairs: [('с', 'гана'), ('пи', 'ли'), ('ш', 'ке'), ('ну', 'лись'), ('ло', 'ю'), ('му', 'к'), ('ме', 'что'), ('ры', 'е'), ('кры', 'лья'), ('тру', 'п')]
# max_pairs: [('говори', 'ть'), ('ва', 'йте'), ('шу', 'т'), ('му', 'дро'), ('ку', 'п'), ('по', 'го'), ('ок', 'на'), ('м', 'ча'), ('пу', 'шки'), ('ино', 'гда')]
# max_pairs: [('свя', 'ты'), ('с', 'ит'), ('ши', 'шь'), ('ру', 'кою'), ('га', 'н'), ('ше', 'ю'), ('мет', 'а'), ('жи', 'ву'), ('я', 'ро'), ('че', 'ской')]
# max_pairs: [('че', 'сти'), ('ге', 'рой'), ('чер', 'ный'), ('ми', 'лой'), ('мг', 'нов'), ('ска', 'жите'), ('и', 'он'), ('гро', 'ма'), ('дя', 'м'), ('ти', 'шь')]
# max_pairs: [('про', 'шло'), ('встре', 'чу'), ('ма', 'й'), ('ч', 'ок'), ('д', 'жу'), ('сгана', 'рель'), ('ком', 'на'), ('пь', 'е'), ('нес', 'ет'), ('те', 'л')]
# max_pairs: [('сто', 'лько'), ('па', 'сту'), ('ро', 'зы'), ('у', 'ро'), ('ры', 'з'), ('жизнь', 'ю'), ('ги', 'б'), ('ра', 'ть'), ('слы', 'ш'), ('жела', 'нья')]
# max_pairs: [('сколь', 'з'), ('нена', 'ви'), ('ли', 'во'), ('зе', 'в'), ('и', 'кси'), ('еди', 'не'), ('доро', 'га'), ('ли', 'л'), ('вы', 'ра'), ('бе', 'ско')]
# max_pairs: [('се', 'ль'), ('не', 'ви'), ('чи', 'н'), ('па', 'ро'), ('ста', 'ву'), ('вдо', 'ль'), ('ни', 'це'), ('р', 'ва'), ('за', 'тем'), ('дум', 'чи')]
# max_pairs: [('об', 'ще'), ('голо', 'са'), ('от', 'сут'), ('че', 'ский'), ('ть', 'ме'), ('то', 'ска'), ('золо', 'той'), ('ла', 'в'), ('кре', 'уса'), ('ска', 'л')]
# max_pairs: [('бле', 'стя'), ('ти', 'р'), ('ти', 'м'), ('об', 'ман'), ('гра', 'д'), ('ве', 'дет'), ('бра', 'тья'), ('зна', 'я'), ('пес', 'нь'), ('смотри', 'те')]
# max_pairs: [('ев', 'ро'), ('ру', 'мя'), ('ф', 'она'), ('ст', 'ри'), ('за', 'й'), ('за', 'был'), ('над', 'ца'), ('про', 'шу'), ('тре', 'пе'), ('ог', 'ни')]
# max_pairs: [('ви', 'х'), ('вы', 'ходит'), ('ру', 'ке'), ('при', 'шла'), ('у', 'ка'), ('день', 'ги'), ('ва', 'ются'), ('жи', 'е'), ('ма', 'лень'), ('про', 'хла')]
# max_pairs: [('раз', 'и'), ('шу', 'ю'), ('де', 'ле'), ('жа', 'дно'), ('ко', 'ли'), ('у', 'ха'), ('ре', 'волю'), ('ш', 'ний'), ('от', 'кро'), ('да', 'нья')]
# max_pairs: [('мед', 'ленно'), ('сво', 'ем'), ('стран', 'но'), ('га', 'ть'), ('не', 'ду'), ('за', 'ет'), ('которы', 'х'), ('по', 'дыма'), ('д', 'ная'), ('я', 'л')]
# max_pairs: [('я', 'ми'), ('уже', 'ли'), ('ве', 'ков'), ('пла', 'чет'), ('та', 'кая'), ('на', 'зы'), ('ним', 'фа'), ('ка', 'ет'), ('т', 'ря'), ('дете', 'ль')]
# max_pairs: [('вер', 'ен'), ('из', 'бра'), ('пер', 'вое'), ('ви', 'ч'), ('ри', 'и'), ('те', 'ла'), ('мо', 'к'), ('поэ', 'та'), ('сто', 'ль'), ('вре', 'мени')]
# max_pairs: [('ок', 'тя'), ('до', 'воль'), ('бе', 'жал'), ('не', 'вольно'), ('п', 'ки'), ('ру', 'ю'), ('бо', 'лее'), ('э', 'фи'), ('хо', 'жу'), ('слу', 'га')]
# max_pairs: [('по', 'дума'), ('ци', 'й'), ('м', 'ъ'), ('лю', 'т'), ('заб', 'в'), ('стоя', 'л'), ('чи', 'х'), ('бу', 'ри'), ('ша', 'ет'), ('доб', 'рый')]
# max_pairs: [('сво', 'его'), ('горо', 'да'), ('ло', 'ся'), ('господи', 'н'), ('оди', 'с'), ('агамемно', 'н'), ('джу', 'льет'), ('на', 'пол'), ('зло', 'б'), ('про', 'тя')]
# max_pairs: [('пы', 'ль'), ('сла', 'бы'), ('ста', 'ль'), ('до', 'му'), ('о', 'гром'), ('чи', 'ки'), ('ут', 'ром'), ('т', 'ник'), ('спокой', 'но'), ('ви', 'ла')]
# max_pairs: [('на', 'ру'), ('спо', 'р'), ('э', 'р'), ('с', 'начала'), ('сто', 'ят'), ('сол', 'да'), ('по', 'шел'), ('взя', 'л'), ('дно', 'м'), ('слыша', 'л')]
# max_pairs: [('пол', 'на'), ('ча', 'м'), ('бы', 'тия'), ('слу', 'ж'), ('со', 'зна'), ('пу', 'р'), ('иска', 'ть'), ('мог', 'ли'), ('ле', 'су'), ('у', 'то')]
# max_pairs: [('свет', 'ло'), ('одни', 'м'), ('ми', 'ру'), ('ба', 'ю'), ('жени', 'е'), ('глаза', 'ми'), ('у', 'тро'), ('му', 'жа'), ('че', 'ство'), ('в', 'люб')]
# max_pairs: [('в', 'дво'), ('ставу', 'нин'), ('звез', 'да'), ('смо', 'треть'), ('вра', 'гов'), ('ми', 'ри'), ('мол', 'к'), ('к', 'нул'), ('сто', 'ю'), ('пы', 'х')]
# max_pairs: [('ч', 'ко'), ('без', 'д'), ('ти', 'ли'), ('бо', 'л'), ('н', 'ге'), ('кли', 'темне'), ('по', 'лез'), ('ка', 'на'), ('да', 'ю'), ('е', 'л')]
# max_pairs: [('зо', 'к'), ('по', 'ру'), ('и', 'ск'), ('ч', 'ется'), ('нь', 'ко'), ('ле', 'ст'), ('ствен', 'ной'), ('ко', 'ра'), ('ж', 'ки'), ('ень', 'и')]
# max_pairs: [('герак', 'л'), ('ра', 'но'), ('жа', 'ет'), ('бу', 'ла'), ('ба', 'л'), ('т', 'ится'), ('страда', 'нья'), ('ре', 'ки'), ('бе', 'да'), ('про', 'ш')]
# max_pairs: [('праз', 'дник'), ('голо', 'вы'), ('з', 'вал'), ('чи', 'ны'), ('рас', 'ста'), ('о', 'дет'), ('не', 'бу'), ('лени', 'й'), ('умер', 'еть'), ('за', 'думчи')]
# max_pairs: [('не', 'ту'), ('ме', 'дли'), ('вст', 'ву'), ('о', 'коло'), ('ди', 'они'), ('за', 'ме'), ('боль', 'ш'), ('по', 'лей'), ('слеза', 'ми'), ('те', 'с')]
# max_pairs: [('вели', 'кий'), ('бо', 'льно'), ('са', 'мой'), ('ству', 'ют'), ('с', 'со'), ('ка', 'кое'), ('пы', 'л'), ('друго', 'го'), ('глубо', 'ко'), ('по', 'се')]
# max_pairs: [('бер', 'ет'), ('обла', 'ка'), ('об', 'ре'), ('стра', 'не'), ('но', 'вых'), ('чувст', 'ва'), ('но', 'ва'), ('то', 'ску'), ('це', 'пи'), ('от', 'ли')]
# max_pairs: [('ню', 'ю'), ('ку', 'ла'), ('сты', 'х'), ('по', 'слу'), ('голо', 'ва'), ('бра', 'та'), ('бегу', 'т'), ('не', 'су'), ('уже', 'ль'), ('слы', 'шит')]
# max_pairs: [('мо', 'жешь'), ('печа', 'ть'), ('ди', 'сь'), ('то', 'ро'), ('бра', 'ть'), ('х', 'е'), ('сло', 'вом'), ('е', 'ё'), ('си', 'лу'), ('кото', 'рой')]
# max_pairs: [('сты', 'е'), ('о', 'пу'), ('беско', 'не'), ('у', 'том'), ('ли', 'це'), ('ро', 'го'), ('не', 'р'), ('ад', 'мет'), ('на', 'пе'), ('на', 'ч')]
# max_pairs: [('г', 'нет'), ('взо', 'ром'), ('ка', 'мен'), ('крас', 'ный'), ('бе', 'лые'), ('ешь', 'ся'), ('во', 'к'), ('ствен', 'но'), ('ти', 'ше'), ('ге', 'ра')]
# max_pairs: [('ка', 'пита'), ('францу', 'з'), ('победоноси', 'ков'), ('сторо', 'ны'), ('та', 'ть'), ('мы', 'м'), ('на', 'всегда'), ('так', 'же'), ('печаль', 'ный'), ('скор', 'б')]
# max_pairs: [('жу', 'т'), ('в', 'про'), ('би', 'ли'), ('нас', 'ме'), ('ф', 'ра'), ('ч', 'рез'), ('ле', 'в'), ('т', 'щет'), ('чувст', 'в'), ('у', 'вя')]
# max_pairs: [('лоб', 'за'), ('ж', 'ные'), ('до', 'стой'), ('дей', 'ствие'), ('нача', 'ль'), ('роко', 'вой'), ('пе', 'сен'), ('госпо', 'да'), ('о', 'хот'), ('пле', 'ч')]
# max_pairs: [('у', 'бит'), ('ли', 'ть'), ('кото', 'рая'), ('мер', 'и'), ('стро', 'го'), ('тру', 'да'), ('кро', 'т'), ('пой', 'ду'), ('гра', 'ф'), ('чуж', 'ой')]
# max_pairs: [('в', 'ной'), ('бо', 'в'), ('ды', 'шит'), ('сказа', 'ла'), ('улы', 'ба'), ('до', 'сти'), ('ни', 'цу'), ('одно', 'го'), ('со', 'т'), ('женщи', 'ны')]
# max_pairs: [('хле', 'ба'), ('у', 'пор'), ('бо', 'жь'), ('пред', 'став'), ('про', 'лета'), ('с', 'чет'), ('ба', 'ль'), ('се', 'стра'), ('ф', 'ри'), ('ка', 'д')]
# max_pairs: [('дру', 'гим'), ('спо', 'ко'), ('чер', 'ты'), ('взо', 'ры'), ('ле', 'ет'), ('про', 'па'), ('вер', 'ю'), ('прав', 'ду'), ('ш', 'кой'), ('во', 'про')]
# max_pairs: [('ба', 'н'), ('долж', 'ны'), ('на', 'чина'), ('золо', 'то'), ('ф', 'он'), ('и', 'мени'), ('д', 'ю'), ('ти', 'н'), ('се', 'вер'), ('во', 'ду')]
# max_pairs: [('рас', 'су'), ('ва', 'лись'), ('звез', 'д'), ('е', 'к'), ('за', 'будь'), ('от', 'дох'), ('судь', 'бе'), ('т', 'ет'), ('р', 'ный'), ('долж', 'на')]
# max_pairs: [('по', 'спе'), ('ро', 'ско'), ('не', 'в'), ('ца', 'ми'), ('тек', 'сте'), ('ка', 'са'), ('бь', 'ет'), ('зы', 'б'), ('ч', 'кой'), ('е', 'ха')]
# max_pairs: [('ра', 'сто'), ('мер', 'ца'), ('до', 'бра'), ('я', 'з'), ('ля', 'я'), ('ми', 'ром'), ('со', 'кры'), ('плака', 'ть'), ('чен', 'ный'), ('мне', 'й')]
# max_pairs: [('пер', 'ем'), ('зем', 'лей'), ('лицо', 'м'), ('благо', 'сло'), ('встре', 'ча'), ('наде', 'жда'), ('ба', 'к'), ('не', 'сли'), ('ши', 'б'), ('не', 'дви')]
# max_pairs: [('чно', 'е'), ('па', 'д'), ('от', 'ва'), ('вес', 'на'), ('д', 'вой'), ('небе', 'са'), ('з', 'ря'), ('э', 'лла'), ('гово', 'рю'), ('ма', 'л')]
# max_pairs: [('ли', 'в'), ('обе', 'ща'), ('бе', 'ли'), ('сно', 'в'), ('жа', 'я'), ('тол', 'пы'), ('бро', 'шен'), ('тай', 'ны'), ('во', 'ин'), ('че', 'ских')]
# max_pairs: [('фа', 'бри'), ('мо', 'з'), ('несчаст', 'ный'), ('пе', 'щер'), ('свет', 'лый'), ('цвет', 'ов'), ('с', 'п'), ('воскре', 'с'), ('неж', 'ной'), ('лю', 'дям')]
# max_pairs: [('ни', 'ю'), ('н', 'ным'), ('бо', 'б'), ('здра', 'вству'), ('са', 'мый'), ('пе', 'ц'), ('близ', 'ко'), ('доро', 'гу'), ('ве', 'сен'), ('чу', 'жды')]
# max_pairs: [('вто', 'рой'), ('ста', 'нь'), ('при', 'ш'), ('мо', 'ем'), ('с', 'мыс'), ('росси', 'и'), ('га', 'ли'), ('ва', 'ем'), ('дож', 'дь'), ('же', 'ле')]
# max_pairs: [('под', 'ходит'), ('не', 'сла'), ('та', 'ли'), ('ли', 'м'), ('узна', 'ть'), ('ска', 'зы'), ('ста', 'ну'), ('а', 'рома'), ('ё', 'р'), ('ря', 'ды')]
# max_pairs: [('бре', 'д'), ('доро', 'гой'), ('с', 'ро'), ('бле', 'дне'), ('ти', 'лся'), ('не', 'о'), ('кро', 'ме'), ('жи', 'ве'), ('та', 'кого'), ('крестья', 'нин')]
# max_pairs: [('лен', 'о'), ('сви', 'ре'), ('не', 'сколько'), ('сту', 'к'), ('бес', 'пло'), ('пусты', 'не'), ('ба', 'х'), ('при', 'ходит'), ('ми', 'ла'), ('го', 'н')]
# max_pairs: [('чу', 'да'), ('да', 'ст'), ('пе', 'ра'), ('два', 'дцать'), ('о', 'гра'), ('могу', 'т'), ('с', 'жа'), ('горя', 'т'), ('ь', 'е'), ('на', 'зна')]
# max_pairs: [('не', 'чисты'), ('му', 'дре'), ('музы', 'ка'), ('клитемне', 'стра'), ('высо', 'ко'), ('ка', 'ча'), ('клю', 'ч'), ('ин', 'тер'), ('ум', 'ру'), ('жде', 'м')]
# max_pairs: [('пред', 'мет'), ('ди', 'ла'), ('чь', 'е'), ('гре', 'х'), ('ня', 'ла'), ('сла', 'ву'), ('мо', 'ля'), ('господ', 'ь'), ('над', 'цать'), ('вст', 'вен')]
# max_pairs: [('ен', 'а'), ('вол', 'на'), ('больш', 'ой'), ('дро', 'жит'), ('объя', 'тья'), ('смотре', 'л'), ('зло', 'дей'), ('да', 'йте'), ('рас', 'се'), ('пти', 'цы')]
# max_pairs: [('всем', 'и'), ('рет', 'а'), ('тру', 'дно'), ('по', 'ез'), ('маль', 'чик'), ('фо', 'с'), ('ш', 'та'), ('впро', 'чем'), ('рабочи', 'х'), ('анти', 'го')]
# max_pairs: [('джульет', 'та'), ('ло', 'жь'), ('во', 'р'), ('з', 'вать'), ('вы', 'р'), ('раз', 'о'), ('бле', 'дный'), ('го', 'ри'), ('а', 'га'), ('стви', 'я')]
# max_pairs: [('за', 'с'), ('и', 'в'), ('ла', 'ски'), ('ш', 'ля'), ('боль', 'ной'), ('ла', 'д'), ('ша', 'х'), ('ти', 'ра'), ('с', 'хва'), ('тю', 'рь')]
# max_pairs: [('мину', 'ту'), ('у', 'сы'), ('г', 'ений'), ('ну', 'ться'), ('по', 'шли'), ('мо', 'лю'), ('еди', 'н'), ('душ', 'но'), ('стра', 'ны'), ('пре', 'де')]
# max_pairs: [('ли', 'я'), ('ба', 'ры'), ('ви', 'з'), ('трет', 'ий'), ('вя', 'з'), ('вста', 'ет'), ('чер', 'ной'), ('до', 'сто'), ('те', 'ли'), ('глаза', 'х')]
# max_pairs: [('пы', 'ли'), ('бу', 'к'), ('ре', 'к'), ('пе', 'вец'), ('бес', 'силь'), ('ве', 'ро'), ('по', 'зво'), ('зи', 'и'), ('с', 'жи'), ('одис', 'сей')]
# max_pairs: [('взя', 'ть'), ('ма', 'ту'), ('ждень', 'е'), ('сво', 'д'), ('ко', 'раб'), ('бо', 'е'), ('ро', 'пот'), ('ш', 'ем'), ('за', 'ри'), ('дите', 'ль')]
# max_pairs: [('ди', 'я'), ('ста', 'нов'), ('е', 'хал'), ('капу', 'лет'), ('щ', 'енья'), ('бере', 'гу'), ('игра', 'ет'), ('яр', 'ко'), ('ле', 'я'), ('ч', 'ную')]
# max_pairs: [('еди', 'ный'), ('бе', 'лой'), ('вол', 'н'), ('ген', 'е'), ('вер', 'ить'), ('ру', 'б'), ('одна', 'жды'), ('по', 'теря'), ('мла', 'ден'), ('повто', 'ря')]
# max_pairs: [('зем', 'ных'), ('кон', 'чи'), ('рас', 'кры'), ('возвра', 'ща'), ('изве', 'стно'), ('пи', 'ро'), ('смот', 'рю'), ('до', 'ме'), ('а', 'пол'), ('он', 'ъ')]
# max_pairs: [('жа', 'й'), ('про', 'дол'), ('тай', 'ной'), ('мень', 'ше'), ('свет', 'ом'), ('че', 'ства'), ('се', 'стры'), ('все', 'ленной'), ('у', 'бе'), ('дол', 'г')]
# max_pairs: [('ме', 'ло'), ('вс', 'ему'), ('м', 'ноги'), ('писа', 'ть'), ('и', 'ван'), ('пока', 'зы'), ('неве', 'до'), ('праз', 'дни'), ('ж', 'ным'), ('се', 'дой')]
# ...
# max_pairs: [('дума', 'ть'), ('прой', 'дет'), ('оча', 'х'), ('ста', 'ми'), ('вели', 'ча'), ('прекрас', 'ной'), ('о', 'су'), ('золо', 'тые'), ('тай', 'ный'), ('то', 'ске')]
# max_pairs: [('ро', 'п'), ('ок', 'ном'), ('ла', 'до'), ('моги', 'ле'), ('от', 'цом'), ('в', 'ля'), ('та', 'ла'), ('по', 'нят'), ('х', 'ру'), ('ш', 'ней')]
# max_pairs: [('р', 'ной'), ('та', 'р'), ('на', 'ло'), ('поля', 'х'), ('сол', 'не'), ('гра', 'м'), ('деся', 'т'), ('синь', 'ора'), ('ч', 'ком'), ('у', 'споко')]
# max_pairs: [('вет', 'ра'), ('жно', 'сть'), ('неж', 'ных'), ('мол', 'вил'), ('м', 'но'), ('без', 'мер'), ('цвет', 'у'), ('рас', 'сказы'), ('чита', 'ть'), ('наро', 'ду')]
# max_pairs: [('при', 'ста'), ('впол', 'не'), ('че', 'ски'), ('н', 'д'), ('рабо', 'ты'), ('зи', 'я'), ('ма', 'ма'), ('репли', 'ка'), ('бо', 'ка'), ('ца', 'ре')]
# max_pairs: [('вший', 'ся'), ('ро', 'ман'), ('бес', 'покой'), ('о', 'гля'), ('лета', 'ет'), ('в', 'даль'), ('мгнов', 'енье'), ('з', 'им'), ('по', 'ди'), ('ре', 'б')]
# max_pairs: [('раз', 'де'), ('глуби', 'не'), ('сла', 'вя'), ('тен', 'ей'), ('сту', 'пил'), ('за', 'мен'), ('с', 'еть'), ('при', 'ба'), ('за', 'ня'), ('па', 'сть')]
# max_pairs: [('ите', 'ли'), ('дума', 'ю'), ('придет', 'ся'), ('вы', 'с'), ('благо', 'уха'), ('жи', 'вот'), ('ве', 'ди'), ('пу', 'дов'), ('з', 'м'), ('ахи', 'л')]
# max_pairs: [('надца', 'тое'), ('отсут', 'ствуют'), ('за', 'слу'), ('безум', 'но'), ('послу', 'ш'), ('ча', 'сов'), ('чи', 'ли'), ('голу', 'бы'), ('ав', 'гу'), ('скор', 'би')]
# max_pairs: [('но', 'гами'), ('яс', 'ный'), ('и', 'гру'), ('ви', 'ду'), ('ужас', 'ный'), ('уби', 'л'), ('ти', 'ла'), ('о', 'шиб'), ('стру', 'и'), ('мо', 'роз')]
# max_pairs: [('по', 'зо'), ('пи', 'с'), ('ба', 'гря'), ('н', 'ны'), ('хоте', 'ла'), ('гор', 'дый'), ('по', 'сты'), ('а', 'ра'), ('ребен', 'ка'), ('со', 'еди')]
# max_pairs: [('хри', 'сто'), ('вь', 'те'), ('по', 'став'), ('пло', 'ть'), ('с', 'рок'), ('бога', 'м'), ('те', 'ат'), ('кни', 'г'), ('та', 'в'), ('ба', 'ри')]
# max_pairs: [('слав', 'ный'), ('у', 'едине'), ('ле', 'сов'), ('ок', 'ли'), ('чи', 'ст'), ('не', 'подви'), ('ль', 'ется'), ('тяж', 'ко'), ('наве', 'ки'), ('э', 'ль')]
# max_pairs: [('ту', 'ч'), ('кото', 'рую'), ('ч', 'на'), ('про', 'шел'), ('последни', 'е'), ('в', 'шая'), ('ш', 'ту'), ('отдох', 'нуть'), ('зна', 'ла'), ('ответ', 'а')]
# max_pairs: [('зву', 'чит'), ('по', 'про'), ('дро', 'жь'), ('ней', 'ший'), ('тай', 'ну'), ('ви', 'де'), ('сдела', 'л'), ('ам', 'фит'), ('фит', 'ри'), ('ф', 'ан')]
# max_pairs: [('амфит', 'ри'), ('у', 'ходят'), ('пари', 'ж'), ('профе', 'ссор'), ('при', 'ем'), ('е', 'ст'), ('царев', 'на'), ('е', 'лен'), ('ко', 'ри'), ('сужден', 'о')]
# max_pairs: [('де', 'вя'), ('боя', 'з'), ('глу', 'хой'), ('со', 'г'), ('ра', 'ет'), ('преле', 'ст'), ('безум', 'ный'), ('пти', 'ца'), ('стару', 'ха'), ('ука', 'зы')]
# max_pairs: [('ли', 'цу'), ('ть', 'ма'), ('ско', 'в'), ('ку', 'пец'), ('тро', 'й'), ('ч', 'он'), ('алта', 'рь'), ('гре', 'зы'), ('смерт', 'ных'), ('об', 'я')]
# max_pairs: [('полухо', 'рие'), ('у', 'чен'), ('рен', 'о'), ('чи', 'в'), ('ты', 'ми'), ('тра', 'вы'), ('ле', 'жал'), ('ня', 'м'), ('сты', 'м'), ('ч', 'ны')]
# max_pairs: [('о', 'не'), ('ю', 'ных'), ('с', 'плет'), ('одно', 'му'), ('жда', 'ла'), ('зем', 'ные'), ('цвета', 'ми'), ('от', 'дыха'), ('н', 'ное'), ('же', 'г')]
# max_pairs: [('на', 'пря'), ('за', 'х'), ('сва', 'дь'), ('поме', 'щи'), ('лаодами', 'я'), ('ко', 'лен'), ('из', 'мени'), ('не', 'вер'), ('блажен', 'ство'), ('ре', 'кой')]
# max_pairs: [('ввер', 'х'), ('р', 'жа'), ('ну', 'тся'), ('д', 'ны'), ('крас', 'не'), ('жи', 'ви'), ('вечно', 'сть'), ('раз', 'ъ'), ('знако', 'мый'), ('ко', 'сы')]
# max_pairs: [('гре', 'мит'), ('за', 'клю'), ('мило', 'сти'), ('лен', 'ным'), ('чет', 'а'), ('ль', 'ные'), ('кото', 'рого'), ('са', 'по'), ('з', 'он'), ('ер', 'е')]
# max_pairs: [('гра', 'мо'), ('то', 'ль'), ('пер', 'т'), ('мер', 'ку'), ('фо', 'ри'), ('ли', 'зан'), ('ди', 'кий'), ('з', 'лые'), ('пла', 'ч'), ('за', 'нима')]
# max_pairs: [('ж', 'ку'), ('любез', 'ный'), ('д', 'кой'), ('случай', 'но'), ('стре', 'лы'), ('ча', 'лся'), ('весе', 'л'), ('моли', 'ться'), ('сте', 'пи'), ('гля', 'дел')]
# max_pairs: [('лу', 'г'), ('ва', 'ша'), ('посте', 'ли'), ('жи', 'ва'), ('у', 'бить'), ('бле', 'ском'), ('по', 'сы'), ('тай', 'на'), ('ня', 'ми'), ('про', 'шли')]
# max_pairs: [('на', 'ли'), ('тыся', 'чи'), ('древ', 'ний'), ('преж', 'нему'), ('покор', 'но'), ('за', 'се'), ('гру', 'з'), ('праз', 'дно'), ('ту', 'н'), ('а', 'дра')]
# max_pairs: [('дим', 'ит'), ('счасти', 'я'), ('вс', 'помина'), ('оста', 'лось'), ('смот', 'рят'), ('пор', 'трет'), ('ску', 'чно'), ('г', 'нуть'), ('уви', 'дел'), ('го', 'ни')]
# max_pairs: [('сво', 'ему'), ('уны', 'ло'), ('най', 'ду'), ('под', 'нял'), ('весе', 'лье'), ('ле', 'ли'), ('но', 'сят'), ('без', 'наде'), ('ку', 'ри'), ('дал', 'ё')]
# max_pairs: [('спа', 'са'), ('при', 'ди'), ('за', 'ди'), ('зна', 'мен'), ('ста', 'рая'), ('га', 'да'), ('ло', 'ма'), ('воз', 'мо'), ('стоя', 'ть'), ('лет', 'о')]
# max_pairs: [('лу', 'га'), ('из', 'ба'), ('ше', 'сть'), ('о', 'до'), ('гру', 'сть'), ('видень', 'я'), ('хоро', 'ш'), ('ве', 'лел'), ('ожи', 'да'), ('у', 'ще')]
# max_pairs: [('зака', 'та'), ('про', 'те'), ('с', 'пят'), ('хи', 'щ'), ('дру', 'ги'), ('встре', 'чи'), ('ва', 'ря'), ('и', 'гры'), ('радо', 'стью'), ('тру', 'дом')]
# max_pairs: [('зи', 'л'), ('пло', 'д'), ('ди', 'н'), ('об', 'ви'), ('чи', 'не'), ('зо', 'л'), ('ч', 'ник'), ('спо', 'соб'), ('про', 'хо'), ('ры', 'в')]
# max_pairs: [('ви', 'е'), ('во', 'в'), ('воль', 'те'), ('по', 'сто'), ('зна', 'ете'), ('элек', 'три'), ('крас', 'ные'), ('ан', 'дро'), ('ком', 'со'), ('по', 'стой')]
# max_pairs: [('чер', 'ных'), ('лю', 'дь'), ('стре', 'ми'), ('ю', 'ный'), ('у', 'л'), ('крова', 'вый'), ('вс', 'пых'), ('до', 'су'), ('сте', 'пь'), ('весе', 'ли')]
# max_pairs: [('плен', 'я'), ('уй', 'ти'), ('про', 'шла'), ('помо', 'чь'), ('те', 'пло'), ('дли', 'во'), ('на', 'сле'), ('д', 'ки'), ('по', 'лю'), ('крас', 'ная')]
# max_pairs: [('ли', 'ц'), ('ве', 'ду'), ('ду', 'хом'), ('сы', 'п'), ('лен', 'ная'), ('гражда', 'н'), ('свя', 'то'), ('зу', 'бы'), ('мо', 'ра'), ('ско', 'н')]
# max_pairs: [('амфитри', 'он'), ('алек', 'сан'), ('х', 'му'), ('га', 'ни'), ('г', 'воз'), ('чи', 'во'), ('меч', 'ом'), ('пре', 'ль'), ('се', 'ла'), ('после', 'дней')]
# max_pairs: [('пу', 'т'), ('стру', 'ны'), ('у', 'зор'), ('жерт', 'вы'), ('за', 'бе'), ('плы', 'вет'), ('сви', 'ст'), ('игра', 'л'), ('шен', 'ный'), ('о', 'боль')]
# max_pairs: [('пот', 'ря'), ('жда', 'ет'), ('раз', 'би'), ('о', 'ка'), ('голо', 'ве'), ('вер', 'ы'), ('на', 'шего'), ('го', 'дов'), ('с', 'да'), ('по', 'ря')]
# max_pairs: [('зи', 'на'), ('воз', 'ник'), ('з', 'в'), ('чен', 'ы'), ('фе', 'б'), ('а', 'с'), ('пожа', 'р'), ('гне', 'ва'), ('в', 'миг'), ('в', 'ско')]
# max_pairs: [('ко', 'ни'), ('бь', 'ется'), ('рабо', 'в'), ('вз', 'дыма'), ('запа', 'х'), ('ра', 'т'), ('гроз', 'но'), ('плака', 'л'), ('цвет', 'ет'), ('наде', 'ждой')]
# max_pairs: [('стя', 'х'), ('тем', 'ных'), ('сти', 'л'), ('золо', 'та'), ('жа', 'ла'), ('сем', 'ья'), ('род', 'ные'), ('неж', 'ные'), ('соб', 'ствен'), ('про', 'лет')]
# max_pairs: [('ста', 'рец'), ('душ', 'ка'), ('ра', 'ста'), ('ль', 'ных'), ('ма', 'лю'), ('ба', 'тю'), ('уви', 'деть'), ('кри', 'ки'), ('дво', 'рец'), ('любо', 'вни')]
# max_pairs: [('ти', 'ре'), ('ти', 'и'), ('рас', 'пла'), ('тро', 'ян'), ('у', 'мы'), ('раз', 'но'), ('бы', 'стры'), ('неиз', 'бе'), ('гна', 'л'), ('опа', 'с')]
# max_pairs: [('и', 'гро'), ('ми', 'но'), ('ро', 'вно'), ('вит', 'я'), ('м', 'ногих'), ('поло', 'ви'), ('игра', 'ть'), ('море', 'м'), ('в', 'пи'), ('пре', 'вра')]
# max_pairs: [('обы', 'чай'), ('ле', 'пе'), ('безум', 'ной'), ('сто', 'ны'), ('ог', 'нен'), ('мер', 'тво'), ('при', 'ня'), ('подру', 'ги'), ('к', 'ер'), ('у', 'каза')]
# max_pairs: [('ви', 'ль'), ('гря', 'зь'), ('гим', 'н'), ('э', 'ди'), ('зев', 'са'), ('сто', 'нет'), ('но', 'сил'), ('подви', 'г'), ('куз', 'нец'), ('пер', 'и')]
# max_pairs: [('мерт', 'вый'), ('на', 'ря'), ('от', 'туда'), ('хра', 'ня'), ('воз', 'му'), ('кре', 'м'), ('зме', 'я'), ('наро', 'ды'), ('ку', 'дри'), ('ве', 'ки')]
# max_pairs: [('ла', 'вра'), ('гор', 'д'), ('вол', 'ной'), ('многи', 'е'), ('обра', 'тно'), ('не', 'пре'), ('рен', 'ный'), ('му', 'за'), ('двер', 'ей'), ('безмол', 'в')]
# max_pairs: [('ста', 'рых'), ('от', 'того'), ('пес', 'ней'), ('кла', 'ня'), ('вос', 'ста'), ('а', 'ка'), ('за', 'чер'), ('ер', 'бур'), ('т', 'ита'), ('с', 'пло')]
# max_pairs: [('гер', 'ми'), ('си', 'пе'), ('семя', 'чко'), ('зна', 'ли'), ('по', 'лет'), ('ве', 'дут'), ('дрожа', 'т'), ('хи', 'е'), ('га', 'ют'), ('с', 'бира')]
# max_pairs: [('жда', 'ли'), ('кораб', 'ль'), ('лете', 'ли'), ('коло', 'коль'), ('при', 'ми'), ('ку', 'дря'), ('д', 'ную'), ('ре', 'вно'), ('на', 'каза'), ('вы', 'пол')]
# max_pairs: [('при', 'ле'), ('хоте', 'лось'), ('моги', 'л'), ('пят', 'на'), ('све', 'чи'), ('ма', 'стер'), ('пло', 'хо'), ('вож', 'дь'), ('ё', 'тся'), ('уч', 'ре')]
# max_pairs: [('до', 'лой'), ('октя', 'брь'), ('соци', 'али'), ('рабо', 'чего'), ('мая', 'ковский'), ('фос', 'фори'), ('ви', 'й'), ('тер', 'за'), ('по', 'у'), ('сдела', 'ть')]
# max_pairs: [('трепе', 'щет'), ('у', 'кры'), ('бер', 'у'), ('восто', 'к'), ('була', 'т'), ('це', 'пь'), ('зелен', 'ый'), ('ну', 'ло'), ('же', 'ство'), ('с', 'пя')]
# max_pairs: [('за', 'мы'), ('про', 'шед'), ('пи', 'шу'), ('как', 'ую'), ('при', 'ка'), ('ли', 'ло'), ('хозя', 'ин'), ('с', 'нима'), ('т', 'ят'), ('ку', 'пи')]
# max_pairs: [('ря', 'х'), ('до', 'ку'), ('уста', 'ло'), ('тво', 'рец'), ('и', 'ны'), ('по', 'ды'), ('ш', 'ни'), ('ба', 'я'), ('ра', 'чи'), ('раз', 'ных')]
# max_pairs: [('каж', 'дым'), ('на', 'вли'), ('жен', 'е'), ('воро', 'та'), ('ж', 'ка'), ('ста', 'ти'), ('ти', 'ки'), ('ль', 'да'), ('фи', 'ло'), ('каж', 'дого')]
# max_pairs: [('двор', 'ца'), ('ми', 'ли'), ('ми', 'ни'), ('пожалуй', 'ста'), ('гражда', 'не'), ('вело', 'сипе'), ('бой', 'ся'), ('го', 'рой'), ('наши', 'м'), ('за', 'ле')]
# max_pairs: [('ужа', 'сно'), ('ко', 'вы'), ('сло', 'вам'), ('вели', 'т'), ('и', 'щу'), ('раз', 'ом'), ('чу', 'ю'), ('ни', 'кому'), ('хот', 'ят'), ('ру', 'чей')]
# max_pairs: [('глубо', 'кой'), ('раз', 'ор'), ('бу', 'н'), ('ша', 'п'), ('ви', 'в'), ('лет', 'ся'), ('преж', 'них'), ('горо', 'де'), ('к', 'лет'), ('о', 'сужден')]
# max_pairs: [('помни', 'ть'), ('без', 'образ'), ('видень', 'е'), ('х', 'мель'), ('гре', 'б'), ('па', 'я'), ('за', 'т'), ('весе', 'лья'), ('пари', 'с'), ('жела', 'нье')]
# max_pairs: [('ве', 'я'), ('зи', 'н'), ('те', 'ля'), ('д', 'вен'), ('вен', 'ад'), ('ля', 'ю'), ('при', 'кры'), ('л', 'ки'), ('чи', 'ка'), ('пу', 'х')]
# max_pairs: [('двен', 'ад'), ('ан', 'т'), ('ху', 'дож'), ('ху', 'до'), ('нет', 'ер'), ('вет', 'ви'), ('бо', 'ле'), ('верши', 'ны'), ('ходи', 'ли'), ('сте', 'кла')]
# max_pairs: [('ш', 'них'), ('тво', 'ем'), ('чи', 'нов'), ('сло', 'м'), ('сла', 'б'), ('ко', 'ла'), ('пе', 'ль'), ('ни', 'где'), ('во', 'сь'), ('ску', 'ки')]
# max_pairs: [('ви', 'и'), ('че', 'е'), ('хоро', 'ша'), ('ча', 'са'), ('на', 'го'), ('тро', 'и'), ('даф', 'на'), ('лу', 'чами'), ('от', 'дать'), ('у', 'пря')]
# max_pairs: [('не', 'от'), ('судь', 'бу'), ('боги', 'ни'), ('ко', 'сть'), ('ка', 'в'), ('любо', 'ви'), ('е', 'я'), ('во', 'ен'), ('пти', 'ц'), ('другу', 'ю')]
# max_pairs: [('воль', 'ный'), ('итель', 'ных'), ('вле', 'чет'), ('ще', 'ки'), ('ша', 'й'), ('дли', 'нный'), ('пусти', 'л'), ('деви', 'ца'), ('жен', 'ой'), ('при', 'ме')]
# max_pairs: [('гна', 'ть'), ('род', 'ных'), ('ш', 'ер'), ('вер', 'я'), ('ска', 'ть'), ('сла', 'вно'), ('сила', 'х'), ('красо', 'та'), ('ж', 'ней'), ('дене', 'г')]
# max_pairs: [('тихо', 'й'), ('тек', 'ст'), ('молча', 'ть'), ('ба', 'рин'), ('при', 'каза'), ('жени', 'й'), ('е', 'ва'), ('си', 'й'), ('пет', 'ербур'), ('мер', 'ы')]
# max_pairs: [('де', 'д'), ('жи', 'р'), ('фи', 'ван'), ('льно', 'е'), ('высо', 'кой'), ('бле', 'дна'), ('пе', 'сок'), ('солда', 'т'), ('вра', 'жде'), ('дне', 'в')]
# max_pairs: [('доли', 'ны'), ('гро', 'за'), ('вни', 'зу'), ('страда', 'нье'), ('слыша', 'ть'), ('тро', 'н'), ('у', 'глу'), ('оде', 'жде'), ('те', 'п'), ('писа', 'л')]
# max_pairs: [('вечер', 'ний'), ('тай', 'но'), ('чи', 'ну'), ('зна', 'ют'), ('не', 'возможно'), ('вече', 'ром'), ('дер', 'жал'), ('по', 'я'), ('ш', 'ок'), ('ля', 'н')]
# max_pairs: [('стихо', 'твор'), ('фран', 'ц'), ('пь', 'ян'), ('без', 'уми'), ('ф', 'рон'), ('э', 'ле'), ('в', 'ходят'), ('по', 'лит'), ('бю', 'ро'), ('те', 'ок')]
# max_pairs: [('кли', 'м'), ('мерку', 'цио'), ('дя', 'сь'), ('печаль', 'ной'), ('спа', 'сти'), ('за', 'мер'), ('ра', 'ны'), ('тя', 'сь'), ('чу', 'жих'), ('пу', 'тем')]
# max_pairs: [('глу', 'хо'), ('в', 'лек'), ('тра', 'ве'), ('сладо', 'сть'), ('кру', 'п'), ('ос', 'ень'), ('е', 'ль'), ('со', 'кру'), ('стви', 'й'), ('бер', 'ез')]
# max_pairs: [('тихо', 'нько'), ('се', 'ли'), ('зна', 'мя'), ('об', 'ру'), ('столет', 'ий'), ('жд', 'ений'), ('си', 'жу'), ('ло', 'жи'), ('о', 'ри'), ('ль', 'ян')]
# max_pairs: [('то', 'чки'), ('бу', 'ты'), ('м', 'ся'), ('свет', 'ла'), ('стер', 'е'), ('ч', 'ите'), ('бра', 'л'), ('скри', 'п'), ('чудо', 'ви'), ('ш', 'ите')]
# max_pairs: [('т', 'ём'), ('ва', 'го'), ('вста', 'нь'), ('ию', 'ля'), ('те', 'ми'), ('лани', 'п'), ('ки', 'клоп'), ('ти', 'баль'), ('за', 'да'), ('тол', 'ку')]
# max_pairs: [('бра', 'ни'), ('пи', 'ру'), ('ко', 'пья'), ('тих', 'им'), ('воздух', 'е'), ('слабы', 'й'), ('лени', 'и'), ('го', 'това'), ('наш', 'ли'), ('суро', 'во')]
# max_pairs: [('слу', 'ги'), ('ребен', 'ок'), ('сни', 'тся'), ('про', 'ходят'), ('за', 'дума'), ('ко', 'стер'), ('из', 'о'), ('от', 'цо'), ('судь', 'бою'), ('сла', 'бо')]
# max_pairs: [('у', 'мом'), ('ству', 'я'), ('бе', 'л'), ('по', 'забы'), ('нача', 'ло'), ('не', 'исто'), ('меч', 'ту'), ('ка', 'ла'), ('ет', 'а'), ('не', 'мало')]
# max_pairs: [('гар', 'мо'), ('со', 'сед'), ('зо', 'ви'), ('до', 'ль'), ('че', 'ского'), ('фа', 'р'), ('г', 'вар'), ('хо', 'ды'), ('без', 'мяте'), ('теат', 'р')]
# max_pairs: [('тро', 'е'), ('буржу', 'а'), ('мо', 'с'), ('рас', 'свет'), ('апол', 'лон'), ('ру', 'га'), ('поли', 'ник'), ('ме', 'ланип'), ('фе', 'окли'), ('ко', 'о')]
# max_pairs: [('ве', 'ден'), ('ди', 'во'), ('са', 'дится'), ('и', 'ст'), ('си', 'дят'), ('вь', 'ется'), ('ли', 'вой'), ('стра', 'дать'), ('се', 'ле'), ('ходи', 'ла')]
# max_pairs: [('слеза', 'х'), ('о', 'мы'), ('ре', 'ке'), ('сча', 'стью'), ('про', 'ст'), ('сви', 'да'), ('стари', 'ка'), ('будет', 'е'), ('чи', 'с'), ('за', 'став')]
# max_pairs: [('небес', 'ной'), ('ше', 'ль'), ('вз', 'и'), ('мечта', 'х'), ('пле', 'мя'), ('ва', 'ля'), ('сказа', 'ли'), ('бь', 'ют'), ('баш', 'ни'), ('от', 'дай')]
# max_pairs: [('уви', 'дишь'), ('па', 'ле'), ('ло', 'па'), ('вре', 'мена'), ('нос', 'ится'), ('оча', 'рова'), ('у', 'гла'), ('дви', 'га'), ('ло', 'рен'), ('прият', 'но')]
# max_pairs: [('ан', 'трак'), ('и', 'забе'), ('дер', 'жит'), ('послуша', 'й'), ('интер', 'е'), ('оста', 'ется'), ('жи', 'ма'), ('бу', 'рь'), ('подъ', 'ем'), ('друго', 'е')]
# max_pairs: [('серде', 'ц'), ('муч', 'енья'), ('жа', 'жду'), ('мерт', 'ве'), ('свобо', 'дный'), ('чь', 'их'), ('три', 'дцать'), ('рас', 'сказ'), ('ж', 'ная'), ('не', 'давно')]
# max_pairs: [('го', 'нит'), ('без', 'уме'), ('ру', 'би'), ('ри', 'ца'), ('ре', 'сни'), ('сви', 'данья'), ('сме', 'ется'), ('ме', 'ц'), ('дет', 'ям'), ('з', 'р')]
# max_pairs: [('жен', 'ные'), ('деву', 'шка'), ('слу', 'чи'), ('с', 'ход'), ('арома', 'т'), ('ж', 'ного'), ('бо', 'ли'), ('ень', 'ка'), ('явля', 'ется'), ('прибли', 'жа')]
# max_pairs: [('сказ', 'ки'), ('эо', 'л'), ('здравству', 'й'), ('из', 'об'), ('холо', 'дно'), ('жен', 'ных'), ('роди', 'лся'), ('ме', 'ди'), ('улыб', 'ка'), ('ли', 'сты')]
# max_pairs: [('гу', 'дит'), ('оча', 'ми'), ('ж', 'ья'), ('высо', 'ты'), ('бро', 'дит'), ('не', 'бре'), ('уста', 'лый'), ('за', 'вод'), ('к', 'лей'), ('берего', 'в')]
# max_pairs: [('гла', 'в'), ('пла', 'щ'), ('тра', 'ва'), ('под', 'ра'), ('слы', 'хал'), ('голу', 'бой'), ('ни', 'же'), ('со', 'ль'), ('мо', 'ст'), ('со', 'пер')]
# max_pairs: [('мра', 'чный'), ('не', 'при'), ('пре', 'дел'), ('жд', 'ения'), ('но', 'вое'), ('к', 'су'), ('жи', 'вая'), ('хра', 'ма'), ('раз', 'дум'), ('ша', 'гов')]
# max_pairs: [('моск', 'ве'), ('нос', 'ить'), ('ма', 'ли'), ('ш', 'то'), ('бы', 'т'), ('най', 'дешь'), ('с', 'прав'), ('во', 'дя'), ('паль', 'цы'), ('к', 'ва')]

# %%
print(bpt.token_to_ind)
print(bpt.ind_to_token)
# Out:
# {'ж': 0, ',': 1, 'в': 2, ';': 3, 'ш': 4, '"': 5, 'и': 6, 'р': 7, '\n': 8, 'к': 9, '?': 10, 'д': 11, 'ц': 12, 'л': 13, 'щ': 14, '.': 15, 'м': 16, 'с': 17, 'ю': 18, 'ы': 19, 'х': 20, 'ь': 21, 'г': 22, 'э': 23, 'ъ': 24, 'я': 25, 'й': 26, 'т': 27, '-': 28, 'о': 29, '!': 30, 'ч': 31, 'ё': 32, 'з': 33, 'а': 34, 'п': 35, ':': 36, '(': 37, 'ф': 38, ' ': 39, ')': 40, 'у': 41, 'е': 42, 'н': 43, 'б': 44, '<pad>': 45, '<start>': 46, '<end>': 47, 'ст': 48, 'не': 49, 'на': 50, 'но': 51, 'то': 52, 'ра': 53, 'по': 54, 'ро': 55, 'ен': 56, 'ет': 57, 'во': 58, 'ко': 59, 'ли': 60, 'ка': 61, 'ла': 62, 'го': 63, 'ре': 64, 'ер': 65, 'ны': 66, 'ло': 67, 'ни': 68, 'да': 69, 'ит': 70, 'ва': 71, 'за': 72, 'ть': 73, 'мо': 74, 'ри': 75, 'ль': 76, 'до': 77, 'ле': 78, 'ся': 79, 'ки': 80, 'ру': 81, 'ми': 82, 'ве': 83, 'те': 84, 'ем': 85, 'де': 86, 'бо': 87, 'бе': 88, 'та': 89, 'вы': 90, 'со': 91, 'ви': 92, 'ты': 93, 'сь': 94, 'ма': 95, 'се': 96, 'ча': 97, 'бы': 98, 'ду': 99, 'ме': 100, 'хо': 101, 'ста': 102, 'что': 103, 'ну': 104, 'от': 105, 'про': 106, 'ный': 107, 'ди': 108, 'ти': 109, 'же': 110
 'гово': 307, 'жно': 308, 'бро': 309, 'только': 310, 'бла': 311, 'тер': 312, 'дер': 313, 'род': 314, 'друг': 315, 'кре': 316, 'тебе': 317, 'вол': 318, 'тре': 319, 'лась': 320, 'тру': 321, 'всё': 322, 'нем': 323, 'чит': 324, 'ита': 325, 'пред': 326, 'сме': 327, 'чет': 328, 'сно': 329, 'льно': 330, 'дом': 331, 'три': 332, 'ром': 333, 'жда': 334, 'фи': 335, 'если': 336, 'ему': 337, 'зде': 338, 'тем': 339, 'вст': 340, 'ум': 341, 'меч': 342, 'стре': 343, 'жет': 344, 'гор': 345, 'глу': 346, 'иль': 347, 'лый': 348, 'бли': 349, 'той': 350, 'смер': 351, 'вла': 352, 'быть': 353, 'хи': 354, 'ан': 355, 'бер': 356, 'вал': 35 ...
# {0: 'ж', 1: ',', 2: 'в', 3: ';', 4: 'ш', 5: '"', 6: 'и', 7: 'р', 8: '\n', 9: 'к', 10: '?', 11: 'д', 12: 'ц', 13: 'л', 14: 'щ', 15: '.', 16: 'м', 17: 'с', 18: 'ю', 19: 'ы', 20: 'х', 21: 'ь', 22: 'г', 23: 'э', 24: 'ъ', 25: 'я', 26: 'й', 27: 'т', 28: '-', 29: 'о', 30: '!', 31: 'ч', 32: 'ё', 33: 'з', 34: 'а', 35: 'п', 36: ':', 37: '(', 38: 'ф', 39: ' ', 40: ')', 41: 'у', 42: 'е', 43: 'н', 44: 'б', 45: '<pad>', 46: '<start>', 47: '<end>', 48: 'ст', 49: 'не', 50: 'на', 51: 'но', 52: 'то', 53: 'ра', 54: 'по', 55: 'ро', 56: 'ен', 57: 'ет', 58: 'во', 59: 'ко', 60: 'ли', 61: 'ка', 62: 'ла', 63: 'го', 64: 'ре', 65: 'ер', 66: 'ны', 67: 'ло', 68: 'ни', 69: 'да', 70: 'ит', 71: 'ва', 72: 'за', 73: 'ть', 74: 'мо', 75: 'ри', 76: 'ль', 77: 'до', 78: 'ле', 79: 'ся', 80: 'ки', 81: 'ру', 82: 'ми', 83: 'ве', 84: 'те', 85: 'ем', 86: 'де', 87: 'бо', 88: 'бе', 89: 'та', 90: 'вы', 91: 'со', 92: 'ви', 93: 'ты', 94: 'сь', 95: 'ма', 96: 'се', 97: 'ча', 98: 'бы', 99: 'ду', 100: 'ме', 101: 'хо', 102: 'ста', 103: 'что', 104: 'ну', 105: 'от', 106: 'про', 107: 'ный', 108: 'ди', 109: 'ти', 110: 'же', 111: 'лю', 112: 'ля', 113: 'па', 114: 'при', 115: 'из', 116: 'лу', 117: 'ной', 118: 'как', 119: 'сто', 120: 'ку', 121: 'ей', 122: 'сть', 123: 'ры', 124: 'ши', 125: 'са', 126: 'га', 127: 'чи', 128: 'му', 129: 'он', 130: 'си', 131: 'бу', 132: 'ень', 133: 'ца', 134: 'мы', 135: 'вет', 136: 'раз', 137: 'лы', 138: 'нь', 139: 'жа', 140: 'че', 141: 'шь', 142: 'ды', 143: 'пе', 144: 'пу', 145: 'жи', 146: 'ше', 147: 'вер', 148: 'ря', 149: 'об', 150: 'сти', 151: 'все', 152: 'мен', 153: 'ско', 154: 'пер', 155: 'их', 156: 'ня', 157: 'ска', 158: 'пре', 159: 'ша', 160: 'мне', 161: 'ба', 162: 'лен', 163: 'под', 164: 'ту', 165: 'су', 166: 'ги', 167: 'ных', 168: 'дет', 169: 'вой', 170: 'без', 171: 'ить', 172: 'сво', 173: 'чу', 174: 'нет', 175: 'стра', 176: 'вс', 177: 'ву', 178: 'це', 179: 'зо', 180: 'пи', 181: 'зна', 182: 'гу', 183: 'рас', 184: 'дру', 185: 'кой', 186: 'ные', 187: 'дь', 188: 'его', 189: 'гда', 190: 'би', 191: 'ск', 192: 'это', 193: 'жен', 194: 'мер', 195: 'ют', 196: 'сла', 197: 'щи', 198: 'так', 199: 'дит', 200: 'ите', 201: 'лет', 202: 'ски', 203: 'ней', 204: 'сле', 205: 'лся', 206: 'чер', 207: 'сер', 208: 'чь', 209: 'сло', 210: 'тво', 211: 'ха', 212: 'гла', 213: 'вь', 214: 'вен', 215: 'ще', 216: 'ят', 217: 'мой', 218: 'воз', 219: 'сы', 220: 'ного', 221: 'ная', 222: 'дно', 223: 'кто', 224: 'бя', 225: 'меня', 226: 'ным', 227: 'шу', 228: 'зы', 229: 'где', 230: 'пра', 231: 'вно', 232: 'сли', 233: 'кро', 234: 'ется', 235: 'ком', 236: 'ке', 237: 'вз', 238: 'ени', 239: 'свет', 240: 'над', 241: 'когда', 242: 'гро', 243: 'мя', 244: 'рь', 245: 'сты', 246: 'кра', 247: 'жу', 248: 'она', 249: 'зем', 250: 'пла', 251: 'пере', 252: 'ща', 253: 'чем', 254: 'для', 255: 'лько', 256: 'вот', 257: 'вя', 258: 'бес', 259: 'сту', 260: 'был', 261: 'лись', 262: 'том', 263: 'гра', 264: 'бра', 265: 'спо', 266: 'серд', 267: 'голо', 268: 'ном', 269: 'ге', 270: 'им', 271: 'нам', 272: 'стро', 273: 'кры', 274: 'слу', 275: 'там', 276: 'пы', 277: 'ее', 278: 'тя', 279: 'жиз', 280: 'гру', 281: 'мол', 282: 'ник', 283: 'вра', 284: 'вши', 285: 'дни', 286: 'кру', 287: 'сча', 288: 'ство', 289: 'нас', 290: 'пол', 291: 'день', 292: 'люб', 293: 'вый', 294: 'ков', 295: 'тебя', 296: 'бой', 297: 'сте', 298: 'цы', 299: 'ться', 300: 'чтоб', 301: 'чно', 302: 'кий', 303: 'дол', 304: 'гля', 305: 'тра', 306: 'бле', 307: 'гово', 308: 'жно', 309: 'бро', 310: 'только', 311: 'бла', 312: 'тер', 313: 'дер', 314: 'род', 315: 'друг', 316: 'кре', 317: 'тебе', 318: 'вол', 319: 'тре', 320: 'лась', 321: 'тру', 322: 'всё', 323: 'нем', 324: 'чит', 325: 'ита', 326: 'пред', 327: 'сме', 328: 'чет', 329: 'сно', 330: 'льно', 331: 'дом', 332: 'три', 333: 'ром', 334: 'жда', 335: 'фи', 336: 'если', 337: 'ему', 338: 'зде', 339: 'тем', 340: 'вст', 341: 'ум', 342: 'меч', 343: 'стре', 344: 'жет', 345: 'гор', 346: 'глу', 347: 'иль', 348: 'лый', 349: 'бли', 350: 'той', 351: 'смер', 352: 'вла', 353: 'быть', 354: 'хи', 355: 'ан', 356: 'бер', 357: 'вал ...

# %%
poemes_list = bpt.process_poemes(data['text'].dropna())

# %%
print(''.join([bpt.ind_to_token[ind] for ind in poemes_list[40]]))
# Out:
# забудь опять
# свои надежды;
# об них вздыхать
# судьба невежды;
# она дитя:
# не верь на слово;
# она шутя
# полюбит снова;
# всё, что блестит,
# ее пленяет;
# всё, что грустит,
# ее пугает;
# так облачко
# по небу мчится
# светло, легко;
# оно глядится
# в волнах морских
# поочередно;
# но чужд для них
# прошлец свободный;
# он образ свой
# во всех встречает,
# хоть их порой
# не замечает.

# %%
max_length = max(len(poem) for poem in poemes_list)
max_length
# Out:
# 94592

# %%
poemes_list_sorted = sorted(poemes_list, key=len)

max_length = 1022
split_poemes = []

for poem in poemes_list_sorted:
    if len(poem) > max_length:
        for i in range(0, len(poem), max_length):
            split_poemes.append(poem[i:i + max_length])
    else:
        split_poemes.append(poem)

poemes_list_sorted = split_poemes

# %%
max_length = max(len(poem) for poem in poemes_list_sorted)
max_length
# Out:
# 1022

# %% [markdown]
# ## 3. Генератор батча

# %%
import torch

def batch_gen(poemes_list_sorted, batch_size):
    while True:
        i = torch.randint(0, len(poemes_list_sorted) - batch_size, (1,)).item()
        batch = poemes_list_sorted[i:i+batch_size]
        max_length = len(max(batch, key=len))
        padded_batch = [[bpt.token_to_ind['<start>']] + seq + [bpt.token_to_ind['<pad>']]*(max_length - len(seq)) + [bpt.token_to_ind['<end>']] for seq in batch]
        yield torch.tensor(padded_batch, dtype=torch.long)

next(batch_gen(poemes_list_sorted, 10))
# Out:
# tensor([[  46,  241,   39,  ..., 1642,   15,   47],
#         [  46,  105,   39,  ..., 4030,  112,   47],
#         [  46, 1078, 3187,  ...,  950,   89,   47],
#         ...,
#         [  46, 3455,  137,  ...,   50,   30,   47],
#         [  46, 1993,   39,  ..., 2378,   15,   47],
#         [  46,  362,    1,  ...,  225,   15,   47]])

# %% [markdown]
# ## 3. Модель GPT-1

# %%
from torch import nn
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class Attention(nn.Module):
    def __init__(self, embedding_size, att_size, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.KW = nn.Linear(embedding_size, att_size).to(device)
        self.QW = nn.Linear(embedding_size, att_size).to(device)
        self.VW = nn.Linear(embedding_size, att_size).to(device)
        self.d = float(att_size) ** 0.5
        self.softmax = nn.Softmax(dim=2)
    
    def forward(self, x, ignore):
        K = self.KW(x)
        Q = self.QW(x)
        V = self.VW(x)
        att = torch.einsum('bqd,bkd->bqk', Q, K) / self.d

        ignore_mask = torch.ones(att.shape, device=x.device)
        ignore_mask = torch.einsum(
            'bqk,bk->bqk', 
            ignore_mask, 
            (ignore==0).float()
        )    
        ignore_mask += torch.triu(torch.tril(torch.ones(att.shape, device=x.device)))
        ignore_mask[(ignore_mask==2)] = 1

        att = att.masked_fill((ignore_mask == 0), float('-inf'))
        att = self.softmax(att)
        att = torch.einsum('bqk,bkd->bqd', att, V)
        return att

class MultiHeadAttention(nn.Module):
    def __init__(self, head_count, embedding_size, att_size, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.att_list = nn.ModuleList([Attention(embedding_size, att_size).to(device) for _ in range(head_count)])
        self.union = nn.Linear(att_size * head_count, embedding_size).to(device)

    def forward(self, x, ignore):
        out = torch.cat([head(x, ignore) for head in self.att_list], dim=2)
        return self.union(out)
    
class TransformerBlock(nn.Module):
    def __init__(self, head_count, embedding_size, att_size, dropout,ff_scale = 4, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.norm1 = nn.LayerNorm(embedding_size).to(device)
        self.norm2 = nn.LayerNorm(embedding_size).to(device)
        self.att = MultiHeadAttention(head_count, embedding_size, att_size).to(device)
        self.ff = nn.Sequential(
            nn.Linear(embedding_size, ff_scale * embedding_size).to(device),
            nn.GELU(),
            nn.Linear(ff_scale * embedding_size, embedding_size).to(device)
        ).to(device)
        self.dropout = nn.Dropout(dropout).to(device)
    
    def forward(self, x, ignore):
        x = x + self.dropout(self.att(self.norm1(x), ignore))
        x = x + self.dropout(self.ff(self.norm2(x)))
        return x

class GPT(nn.Module):
    def __init__(self, head_count, tf_block_count, embedding_size, att_size, dropout, max_length=1024, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.embedding_size = embedding_size
        self.pos_encoding = PositionalEncoding(embedding_size, max_length).to(device)
        self.embedding = nn.Embedding(len(bpt.token_to_ind), embedding_size).to(device)
        self.blocks = nn.ModuleList([TransformerBlock(head_count, embedding_size, att_size, dropout) for _ in range(tf_block_count)]).to(device)
        self.fc = nn.Linear(embedding_size, len(bpt.token_to_ind)).to(device)

    def forward(self, x, ignore):
        x = self.embedding(x)
        x = self.pos_encoding(x)
        for block in self.blocks:
            x = block(x, ignore)
        return self.fc(x)
    
class PositionalEncoding(nn.Module):
    def __init__(self, embedding_size, max_length, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pe = torch.zeros(max_length, embedding_size, device=device)
        for pos in range(max_length):
            for i in range(0, embedding_size, 2):
                pos_tensor = torch.tensor(float(pos), dtype=torch.float32, device=self.pe.device)
                exponent = float(2 * i) / float(embedding_size)
                val = pos_tensor / (10000.0 ** exponent)
                self.pe[pos, i] = torch.sin(val)
                self.pe[pos, i+1] = torch.cos(val)
        self.pe = self.pe.unsqueeze(0).to(device)
    
    def forward(self, x):
        return x * self.pe[:, :x.size(1)]
    
def ignore_mask(x):
    return (x == bpt.token_to_ind['<pad>']).to(device)

# %%
from torch.optim import Adam

model = GPT(8, 3, 128, 32, 0.3, max_length=1024)

model.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

print(next(model.parameters()).device)
# Out:
# cuda:0

# %%
class Trainer:
    def __init__(self, model, optimizer, loss_fn, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.model = model
        self.optimizer = optimizer
        self.loss_fn = loss_fn
    
    def train(self, data_gen, epochs, steps_per_epoch):
        for epoch in range(epochs):
            for _ in range(steps_per_epoch):
                try:
                    data = next(data_gen)
                except StopIteration:
                    break
                data = data.to(device)
                self.optimizer.zero_grad()
                ignore = ignore_mask(data)
                out = self.model(data, ignore)
                loss = self.loss_fn(out[:, :-1].reshape(-1, len(bpt.token_to_ind)), data[:, 1:].reshape(-1))
                loss.backward()
                self.optimizer.step()
            print(f"epoch {epoch}:", loss.item())

steps_per_epoch = 10

trainer = Trainer(model, Adam(model.parameters(), lr=1e-3), nn.CrossEntropyLoss(ignore_index=bpt.token_to_ind['<pad>']))

trainer.train(batch_gen(poemes_list_sorted, 10), 10000, steps_per_epoch)

def generate(model, start, max_length):
    with torch.no_grad():
        ignore = ignore_mask(start)
        out = model(start, ignore)
        for _ in range(max_length):
            next_token = torch.argmax(out[:, -1, :])
            if next_token == bpt.token_to_ind['<end>']:
                break
            start = torch.cat([start, next_token.unsqueeze(1)], dim=1)
            ignore = ignore_mask(start)
            out = model(start, ignore)
        return start

start = next(batch_gen(poemes_list_sorted, 1))
generated = generate(model, start, 100)

print(''.join([bpt.ind_to_token[ind] for ind in generated[0]]))
# Out:
# epoch 0: 4.771115779876709
# epoch 1: 4.497039318084717
# epoch 2: 4.462979316711426
# epoch 3: 4.573539733886719
# epoch 4: 4.482378959655762
# epoch 5: 4.467183589935303
# epoch 6: 4.396716117858887
# epoch 7: 4.636803150177002
# epoch 8: 4.365139484405518
# epoch 9: 4.192533016204834
# epoch 10: 4.528005123138428
# epoch 11: 4.419792175292969
# epoch 12: 4.565180778503418
# epoch 13: 4.525610446929932
# epoch 14: 4.552760601043701
# epoch 15: 4.446782112121582
# epoch 16: 4.346632480621338
# epoch 17: 4.433466911315918
# epoch 18: 4.564179420471191
# epoch 19: 4.316680431365967
# epoch 20: 4.28478479385376
# epoch 21: 4.466027736663818
# epoch 22: 4.233577251434326
# epoch 23: 4.393610000610352
# epoch 24: 4.762841701507568
# epoch 25: 4.451239585876465
# epoch 26: 4.218472957611084
# epoch 27: 4.271797180175781
# epoch 28: 4.145555019378662
# epoch 29: 4.220048427581787
# epoch 30: 4.537203788757324
# epoch 31: 4.450421333312988
# epoch 32: 4.405178070068359
# epoch 33: 4.5241780281066895
# epoch 34: 4.34000825881958
# epoch 35: 4.516250133514404
# epoch 36: 4.053343772888184
# epoch 37: 4.3114728927612305
# epoch 38: 4.411505222320557
# epoch 39: 4.2434468269348145
# epoch 40: 4.2928690910339355
# epoch 41: 4.361934661865234
# epoch 42: 4.3953776359558105
# epoch 43: 4.2422637939453125
# epoch 44: 4.356967449188232
# epoch 45: 4.273498058319092
# epoch 46: 4.125988006591797
# epoch 47: 4.266924858093262
# epoch 48: 4.3415656089782715
# epoch 49: 4.427949905395508
# epoch 50: 4.164988040924072
# epoch 51: 4.158445358276367
# epoch 52: 4.6278300285339355
# epoch 53: 4.271431922912598
# epoch 54: 4.2309651374816895
# epoch 55: 4.256084442138672
# epoch 56: 4.240415096282959
# epoch 57: 4.086440563201904
# epoch 58: 4.254740238189697
# epoch 59: 3.6310763359069824
# epoch 60: 4.325377941131592
# epoch 61: 4.210037708282471
# epoch 62: 4.1290202140808105
# epoch 63: 4.277376651763916
# epoch 64: 3.8389298915863037
# epoch 65: 4.180971622467041
# epoch 66: 4.159470558166504
# epoch 67: 4.314645290374756
# epoch 68: 4.202326774597168
# epoch 69: 4.401743412017822
# epoch 70: 4.217628479003906
# epoch 71: 3.91697096824646
# epoch 72: 4.512042045593262
# epoch 73: 4.37601900100708
# epoch 74: 4.218733310699463
# epoch 75: 4.24566125869751
# epoch 76: 4.148479461669922
# epoch 9983: 0.03000599890947342
# epoch 9984: 0.010075836442410946
# epoch 9985: 0.0042565083131194115
# epoch 9986: 0.003909412305802107
# epoch 9987: 0.014630598947405815
# epoch 9988: 0.008559568785130978
# epoch 9989: 0.0033888863399624825
# epoch 9990: 0.01217686478048563
# epoch 9991: 0.02880331687629223
# epoch 9992: 0.03116326406598091
# epoch 9993: 0.01309880893677473
# epoch 9994: 0.02137983776628971
# epoch 9995: 0.0098867267370224
# epoch 9996: 0.011524957604706287
# epoch 9997: 0.031157542020082474
# epoch 9998: 0.019172102212905884
# epoch 9999: 0.013676686212420464
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[121], line 44
#      41         return start
#      43 start = next(batch_gen(poemes_list_sorted, 1))
# ---> 44 generated = generate(model, start, 100)
#      46 print(''.join([bpt.ind_to_token[ind] for ind in generated[0]]))
#
# Cell In[121], line 33, in generate(model, start, max_length)
#      31 with torch.no_grad():
#      32     ignore = ignore_mask(start)
# ---> 33     out = model(start, ignore)
#      34     for _ in range(max_length):
#      35         next_token = torch.argmax(out[:, -1, :])
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[117], line 72, in GPT.forward(self, x, ignore)
#      71 def forward(self, x, ignore):
# ---> 72     x = self.embedding(x)
#      73     x = self.pos_encoding(x)
#      74     for block in self.blocks:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument index in method wrapper_CUDA__index_select)

# %%
torch.save(model.state_dict(), 'Gpt-model.pth')

import json

with open('token_to_ind.json', 'w') as json_file:
    json.dump(bpt.token_to_ind, json_file)

with open('ind_to_token.json', 'w') as json_file:
    json.dump(bpt.ind_to_token, json_file)

# %%
def generate(model, start, max_length):
    with torch.no_grad():
        ignore = ignore_mask(start)
        out = model(start, ignore)
        for _ in range(max_length):
            next_token = torch.argmax(out[:, -1, :])
            if next_token == bpt.token_to_ind['<end>']:
                break
            start = torch.cat([start, next_token.unsqueeze(1)], dim=1)
            ignore = ignore_mask(start)
            out = model(start, ignore)
        return start

start = next(batch_gen(poemes_list_sorted, 9)).to(device)
generated = generate(model, start, 100)

print(''.join([bpt.ind_to_token[ind.item()] for ind in generated[0]]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[130], line 15
#      12         return start
#      14 start = next(batch_gen(poemes_list_sorted, 9)).to(device)
# ---> 15 generated = generate(model, start, 100)
#      17 print(''.join([bpt.ind_to_token[ind.item()] for ind in generated[0]]))
#
# Cell In[130], line 9, in generate(model, start, max_length)
#       7 if next_token == bpt.token_to_ind['<end>']:
#       8     break
# ----> 9 start = torch.cat([start, next_token.unsqueeze(1)], dim=1)
#      10 ignore = ignore_mask(start)
#      11 out = model(start, ignore)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)
